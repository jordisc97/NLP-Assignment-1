# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')

from nltk.corpus import stopwords

import pandas as pd
import scipy
from sklearn import *
import re
from SimpleCountVectorizerAMC import *
from TFIDFVectorizer import *

from nltk.stem import WordNetLemmatizer, SnowballStemmer

import xgboost as xgb
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /opt/anaconda/lib/python3.6/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /opt/anaconda/lib/python3.6/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
"""Given an int32 number, print it in English."""
def int_to_en(num):
    d = { 0 : 'zero', 1 : 'one', 2 : 'two', 3 : 'three', 4 : 'four', 5 : 'five',
          6 : 'six', 7 : 'seven', 8 : 'eight', 9 : 'nine', 10 : 'ten',
          11 : 'eleven', 12 : 'twelve', 13 : 'thirteen', 14 : 'fourteen',
          15 : 'fifteen', 16 : 'sixteen', 17 : 'seventeen', 18 : 'eighteen',
          19 : 'nineteen', 20 : 'twenty',
          30 : 'thirty', 40 : 'forty', 50 : 'fifty', 60 : 'sixty',
          70 : 'seventy', 80 : 'eighty', 90 : 'ninety' }
    k = 1000
    m = k * 1000
    b = m * 1000
    t = b * 1000

    assert(0 <= num)

    if (num < 20):
        return d[num]

    if (num < 100):
        if num % 10 == 0: return d[num]
        else: return d[num // 10 * 10] + '-' + d[num % 10]

    if (num < k):
        if num % 100 == 0: return d[num // 100] + ' hundred'
        else: return d[num // 100] + ' hundred and ' + int_to_en(num % 100)

    if (num < m):
        if num % k == 0: return int_to_en(num // k) + ' thousand'
        else: return int_to_en(num // k) + ' thousand, ' + int_to_en(num % k)

    if (num < b):
        if (num % m) == 0: return int_to_en(num // m) + ' million'
        else: return int_to_en(num // m) + ' million, ' + int_to_en(num % m)

    if (num < t):
        if (num % b) == 0: return int_to_en(num // b) + ' billion'
        else: return int_to_en(num // b) + ' billion, ' + int_to_en(num % b)

    if (num % t == 0): return int_to_en(num // t) + ' trillion'
    else: return int_to_en(num // t) + ' trillion, ' + int_to_en(num % t)

    raise AssertionError('num is too large: %s' % str(num))

# %% [markdown]
# # Count Vectorizer

# %%
train_df = pd.read_csv("./data/quora_train_data.csv")
test_df = pd.read_csv('./data/quora_test_data.csv')

# train_df, test_df = sklearn.model_selection.train_test_split(train_df, test_size=0.1, random_state=123)

# %%
train_df.shape, test_df.shape
# Out:
# ((323432, 6), (80858, 6))

# %%
def cast_list_as_strings(mylist):
    """
    return a list of strings
    """
    assert isinstance(mylist, list), f"the input mylist should be a list it is {type(mylist)}"
    
    # return list(map(lambda x: str(x), all_questions)) # Slower
    return [str(s) for s in mylist]

# %%
all_questions = cast_list_as_strings(list(train_df.loc[:, 'question1'])+list(train_df.loc[:, 'question2']))
print(set(type(x).__name__ for x in all_questions))
# Out:
# {'str'}

# %%
def num_conv(s):
    try:
        return int_to_en(int(s)).replace(",","").replace(" ","_")
    except:
        return s


def my_doc_cleaner(doc,
                  pat=r"[^a-zA-Z0-9]"):
    # Allow alphanumeric characters
    doc_cleaner_pattern=pat
    clean_doc_pattern = re.compile(doc_cleaner_pattern)
    doc_clean = clean_doc_pattern.sub(" ", doc)
    return doc.lower()


# stpw = set(stopwords.words("english"))
stpw = []
question_words = ['who','what','when','where','why','how']

stemmer =  SnowballStemmer(language='english')
lemmatizer = WordNetLemmatizer()

def my_tokenizer_func(doc, 
                      ngrams=(1,3), 
                      numbers_to_words=True,
                      stop_words=stpw,
                      pat=r"(?u)\b\w\S*\w*\b",
                      duplicate_question_words=question_words,
                      lem=True,
                      stem=True,
                      add_num_tokens=True):
    
    # Split using a patterm
#     pat=r"(?u)\b\w\w+\b"
#     pat=r"(?u)\b\w\S*\w*\b"
    token_pattern = re.compile(pat)
    lst = token_pattern.findall(doc)
    
    # Transform numbers into words
    if numbers_to_words:
        lst = list(map(lambda x: num_conv(x), lst))
        
    # Drop stopwords 
    lst = list(filter(lambda x : x not in stop_words, lst))
    
    # Duplicate key_words
    if len(duplicate_question_words)>0:
        lst += [value for value in lst if value.lower() in duplicate_question_words]
    
    #Stemmer
    if stem:
        lst = list(map(lambda x: stemmer.stem(x), lst))
    
    #Lemmatizer 
    if lem:
        lst = list(map(lambda x: lemmatizer.lemmatize(x), lst))
        
    if ngrams==(1,1):
        return lst
    
    # Generate ngrams
    lstRet = []
    for a in range(ngrams[0], ngrams[1]+1):
        if a!=1:
            lstRet+=list(zip(*[lst[i:] for i in range(a)]))
            
    # N-tokens
    if add_num_tokens:
        lst.append(num_conv(str(len(lst))) + 'tokens')
    
    return lstRet if ngrams[0]!=1 else lst+lstRet

# %%
count_vect = SimpleCountVectorizerAMC(
    doc_cleaner_func=my_doc_cleaner,
    tokenizer_func=my_tokenizer_func
)
count_vect.fit(all_questions)
# Out:
# HBox(children=(IntProgress(value=0, max=646864), HTML(value='')))
# SimpleCountVectorizerAMC(doc_cleaner_func=<function my_doc_cleaner at 0x7ff1bc332378>,
#                          doc_cleaner_pattern='[^a-zA-Z]',
#                          dtype=<class 'numpy.float32'>, min_word_counts=1,
#                          token_pattern='(?u)\\b\\w\\w+\\b',
#                          tokenizer_func=<function my_tokenizer_func at 0x7ff1bc332488>,
#                          word_transformer_func=None)

# %%
def get_features_from_df(df, vectorizer):
    """
    returns a sparse matrix containing the features build by the count vectorizer.
    Each row should contain features from question1 and question2.
    """
    q1_casted =  cast_list_as_strings(list(df["question1"]))
    q2_casted =  cast_list_as_strings(list(df["question2"]))
    
    q1 = vectorizer.transform(q1_casted)
    q2 = vectorizer.transform(q2_casted)
    
    X_q1q2 = scipy.sparse.hstack((q1,q2))
        
    return X_q1q2

# %%
# %time X_tr_q1q2 = get_features_from_df(train_df,count_vect)
# %time X_te_q1q2  = get_features_from_df(test_df, count_vect)

X_tr_q1q2.shape, train_df.shape, test_df.shape, X_te_q1q2.shape
# Out:
# CPU times: user 3min 9s, sys: 1.1 s, total: 3min 11s
# Wall time: 3min 6s
# CPU times: user 46.8 s, sys: 96 ms, total: 46.9 s
# Wall time: 46 s
# ((323432, 6595610), (323432, 6), (80858, 6), (80858, 6595610))

# %%
y_train = train_df["is_duplicate"].values
y_test = test_df['is_duplicate'].values

# %% [markdown]
# ## Linear Regression

# %%
# logistic = sklearn.linear_model.LogisticRegression(solver="liblinear", verbose=1, max_iter=100)
# logistic.fit(X_tr_q1q2, y_train)

# %%
# logistic.score(X_tr_q1q2, y_train), logistic.score(X_te_q1q2, y_test)

# %% [markdown]
# ## XGBoost

# %%
# import xgboost as xgb
# from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import accuracy_score

# # PARAM GRID
# param_grid = {}
# param_grid['objective'] = 'binary:logistic'
# param_grid['eval_metric'] = ['auc', 'logloss']   #error: (wrong cases)/#(all cases)
# param_grid['eta'] = 0.02
# param_grid['max_depth'] = 10
# param_grid['n_estimators'] = 300

# d_train = xgb.DMatrix(X_tr_q1q2, label=y_train)  # For sparse matrices
# d_valid = xgb.DMatrix(X_te_q1q2, label=y_test)

# watchlist = [(d_train, 'train'), (d_valid, 'valid')]

# bst = xgb.train(param_grid, d_train, 300, watchlist, early_stopping_rounds=10, verbose_eval=5, )
# #300 # train-auc:0.818362	train-logloss:0.527855	valid-auc:0.801083	valid-logloss:0.53815

# %%
import xgboost as xgb

N = 10000 # With early stopping
xgb_model = xgb.XGBClassifier(n_estimators=N)
xgb_model.fit(X_tr_q1q2, y_train, 
              verbose=10, 
              eval_set=[(X_tr_q1q2, y_train),(X_te_q1q2, y_test)], 
              early_stopping_rounds =10,
              eval_metric=['auc','logloss'],
              )
# Out:
# [0]	validation_0-auc:0.67078	validation_0-logloss:0.65108	validation_1-auc:0.67092	validation_1-logloss:0.65145
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [10]	validation_0-auc:0.75544	validation_0-logloss:0.56808	validation_1-auc:0.75395	validation_1-logloss:0.56953
# [20]	validation_0-auc:0.78594	validation_0-logloss:0.54360	validation_1-auc:0.78222	validation_1-logloss:0.54654
# [30]	validation_0-auc:0.79955	validation_0-logloss:0.53041	validation_1-auc:0.79478	validation_1-logloss:0.53426
# [40]	validation_0-auc:0.80960	validation_0-logloss:0.51946	validation_1-auc:0.80354	validation_1-logloss:0.52448
# [50]	validation_0-auc:0.81633	validation_0-logloss:0.51198	validation_1-auc:0.80914	validation_1-logloss:0.51803
# [60]	validation_0-auc:0.82198	validation_0-logloss:0.50553	validation_1-auc:0.81422	validation_1-logloss:0.51221
# [70]	validation_0-auc:0.82784	validation_0-logloss:0.49894	validation_1-auc:0.81876	validation_1-logloss:0.50670
# [80]	validation_0-auc:0.83189	validation_0-logloss:0.49428	validation_1-auc:0.82205	validation_1-logloss:0.50275
# [90]	validation_0-auc:0.83552	validation_0-logloss:0.48997	validation_1-auc:0.82481	validation_1-logloss:0.49933
# [100]	validation_0-auc:0.83900	validation_0-logloss:0.48613	validation_1-auc:0.82748	validation_1-logloss:0.49639
# [110]	validation_0-auc:0.84127	validation_0-logloss:0.48333	validation_1-auc:0.82916	validation_1-logloss:0.49416
# [120]	validation_0-auc:0.84444	validation_0-logloss:0.47877	validation_1-auc:0.83186	validation_1-logloss:0.49022
# [130]	validation_0-auc:0.84678	validation_0-logloss:0.47568	validation_1-auc:0.83363	validation_1-logloss:0.48779
# [140]	validation_0-auc:0.84922	validation_0-logloss:0.47293	validation_1-auc:0.83545	validation_1-logloss:0.48564
# [150]	validation_0-auc:0.85144	validation_0-logloss:0.47003	validation_1-auc:0.83686	validation_1-logloss:0.48365
# [160]	validation_0-auc:0.85337	validation_0-logloss:0.46773	validation_1-auc:0.83828	validation_1-logloss:0.48195
# [170]	validation_0-auc:0.85569	validation_0-logloss:0.46487	validation_1-auc:0.83986	validation_1-logloss:0.47983
# [180]	validation_0-auc:0.85711	validation_0-logloss:0.46262	validation_1-auc:0.84098	validation_1-logloss:0.47807
# [190]	validation_0-auc:0.85873	validation_0-logloss:0.46061	validation_1-auc:0.84186	validation_1-logloss:0.47685
# [200]	validation_0-auc:0.86002	validation_0-logloss:0.45894	validation_1-auc:0.84284	validation_1-logloss:0.47565
# [210]	validation_0-auc:0.86203	validation_0-logloss:0.45650	validation_1-auc:0.84422	validation_1-logloss:0.47389
# [220]	validation_0-auc:0.86359	validation_0-logloss:0.45472	validation_1-auc:0.84510	validation_1-logloss:0.47282
# [230]	validation_0-auc:0.86499	validation_0-logloss:0.45294	validation_1-auc:0.84607	validation_1-logloss:0.47152
# [240]	validation_0-auc:0.86633	validation_0-logloss:0.45130	validation_1-auc:0.84688	validation_1-logloss:0.47046
# [250]	validation_0-auc:0.86773	validation_0-logloss:0.44960	validation_1-auc:0.84771	validation_1-logloss:0.46937
# [260]	validation_0-auc:0.86904	validation_0-logloss:0.44801	validation_1-auc:0.84848	validation_1-logloss:0.46837
# [270]	validation_0-auc:0.87034	validation_0-logloss:0.44623	validation_1-auc:0.84912	validation_1-logloss:0.46733
# [280]	validation_0-auc:0.87147	validation_0-logloss:0.44479	validation_1-auc:0.84990	validation_1-logloss:0.46626
# [290]	validation_0-auc:0.87272	validation_0-logloss:0.44312	validation_1-auc:0.85083	validation_1-logloss:0.46505
# [300]	validation_0-auc:0.87401	validation_0-logloss:0.44103	validation_1-auc:0.85178	validation_1-logloss:0.46361
# [310]	validation_0-auc:0.87515	validation_0-logloss:0.43968	validation_1-auc:0.85246	validation_1-logloss:0.46277
# [320]	validation_0-auc:0.87619	validation_0-logloss:0.43817	validation_1-auc:0.85311	validation_1-logloss:0.46173
# [330]	validation_0-auc:0.87720	validation_0-logloss:0.43671	validation_1-auc:0.85370	validation_1-logloss:0.46079
# [340]	validation_0-auc:0.87809	validation_0-logloss:0.43555	validation_1-auc:0.85426	validation_1-logloss:0.46007
# [350]	validation_0-auc:0.87902	validation_0-logloss:0.43406	validation_1-auc:0.85486	validation_1-logloss:0.45907
# [360]	validation_0-auc:0.87987	validation_0-logloss:0.43274	validation_1-auc:0.85542	validation_1-logloss:0.45815
# [370]	validation_0-auc:0.88086	validation_0-logloss:0.43139	validation_1-auc:0.85608	validation_1-logloss:0.45722
# [380]	validation_0-auc:0.88191	validation_0-logloss:0.42999	validation_1-auc:0.85652	validation_1-logloss:0.45648
# [390]	validation_0-auc:0.88267	validation_0-logloss:0.42899	validation_1-auc:0.85687	validation_1-logloss:0.45598
# [400]	validation_0-auc:0.88350	validation_0-logloss:0.42801	validation_1-auc:0.85727	validation_1-logloss:0.45548
# [410]	validation_0-auc:0.88418	validation_0-logloss:0.42707	validation_1-auc:0.85770	validation_1-logloss:0.45490
# [420]	validation_0-auc:0.88492	validation_0-logloss:0.42611	validation_1-auc:0.85814	validation_1-logloss:0.45433
# [430]	validation_0-auc:0.88573	validation_0-logloss:0.42504	validation_1-auc:0.85858	validation_1-logloss:0.45366
# [440]	validation_0-auc:0.88648	validation_0-logloss:0.42401	validation_1-auc:0.85899	validation_1-logloss:0.45306
# [450]	validation_0-auc:0.88742	validation_0-logloss:0.42284	validation_1-auc:0.85938	validation_1-logloss:0.45249
# [460]	validation_0-auc:0.88826	validation_0-logloss:0.42175	validation_1-auc:0.85979	validation_1-logloss:0.45194
# [470]	validation_0-auc:0.88947	validation_0-logloss:0.41973	validation_1-auc:0.86076	validation_1-logloss:0.45042
# [480]	validation_0-auc:0.89036	validation_0-logloss:0.41859	validation_1-auc:0.86106	validation_1-logloss:0.44999
# [490]	validation_0-auc:0.89120	validation_0-logloss:0.41746	validation_1-auc:0.86152	validation_1-logloss:0.44932
# [500]	validation_0-auc:0.89182	validation_0-logloss:0.41667	validation_1-auc:0.86183	validation_1-logloss:0.44890
# [510]	validation_0-auc:0.89236	validation_0-logloss:0.41590	validation_1-auc:0.86215	validation_1-logloss:0.44841
# [520]	validation_0-auc:0.89299	validation_0-logloss:0.41506	validation_1-auc:0.86257	validation_1-logloss:0.44786
# [530]	validation_0-auc:0.89391	validation_0-logloss:0.41379	validation_1-auc:0.86297	validation_1-logloss:0.44722
# [540]	validation_0-auc:0.89452	validation_0-logloss:0.41296	validation_1-auc:0.86333	validation_1-logloss:0.44676
# [550]	validation_0-auc:0.89526	validation_0-logloss:0.41203	validation_1-auc:0.86371	validation_1-logloss:0.44622
# [560]	validation_0-auc:0.89590	validation_0-logloss:0.41123	validation_1-auc:0.86397	validation_1-logloss:0.44585
# [570]	validation_0-auc:0.89641	validation_0-logloss:0.41050	validation_1-auc:0.86424	validation_1-logloss:0.44546
# [580]	validation_0-auc:0.89716	validation_0-logloss:0.40940	validation_1-auc:0.86466	validation_1-logloss:0.44484
# [590]	validation_0-auc:0.89780	validation_0-logloss:0.40857	validation_1-auc:0.86488	validation_1-logloss:0.44452
# [600]	validation_0-auc:0.89826	validation_0-logloss:0.40790	validation_1-auc:0.86509	validation_1-logloss:0.44420
# [610]	validation_0-auc:0.89884	validation_0-logloss:0.40708	validation_1-auc:0.86542	validation_1-logloss:0.44372
# [620]	validation_0-auc:0.89938	validation_0-logloss:0.40631	validation_1-auc:0.86576	validation_1-logloss:0.44327
# [630]	validation_0-auc:0.89992	validation_0-logloss:0.40559	validation_1-auc:0.86601	validation_1-logloss:0.44291
# [640]	validation_0-auc:0.90052	validation_0-logloss:0.40454	validation_1-auc:0.86645	validation_1-logloss:0.44220
# [650]	validation_0-auc:0.90111	validation_0-logloss:0.40342	validation_1-auc:0.86696	validation_1-logloss:0.44141
# [660]	validation_0-auc:0.90174	validation_0-logloss:0.40237	validation_1-auc:0.86747	validation_1-logloss:0.44061
# [670]	validation_0-auc:0.90236	validation_0-logloss:0.40153	validation_1-auc:0.86785	validation_1-logloss:0.44008
# [680]	validation_0-auc:0.90286	validation_0-logloss:0.40084	validation_1-auc:0.86809	validation_1-logloss:0.43971
# [690]	validation_0-auc:0.90336	validation_0-logloss:0.40008	validation_1-auc:0.86829	validation_1-logloss:0.43932
# [700]	validation_0-auc:0.90392	validation_0-logloss:0.39926	validation_1-auc:0.86855	validation_1-logloss:0.43894
# [710]	validation_0-auc:0.90443	validation_0-logloss:0.39840	validation_1-auc:0.86876	validation_1-logloss:0.43848
# [720]	validation_0-auc:0.90493	validation_0-logloss:0.39774	validation_1-auc:0.86894	validation_1-logloss:0.43823
# [730]	validation_0-auc:0.90544	validation_0-logloss:0.39699	validation_1-auc:0.86912	validation_1-logloss:0.43790
# [740]	validation_0-auc:0.90599	validation_0-logloss:0.39606	validation_1-auc:0.86947	validation_1-logloss:0.43733
# [750]	validation_0-auc:0.90643	validation_0-logloss:0.39546	validation_1-auc:0.86967	validation_1-logloss:0.43705
# [760]	validation_0-auc:0.90686	validation_0-logloss:0.39485	validation_1-auc:0.86984	validation_1-logloss:0.43683
# [770]	validation_0-auc:0.90726	validation_0-logloss:0.39422	validation_1-auc:0.87007	validation_1-logloss:0.43646
# [780]	validation_0-auc:0.90772	validation_0-logloss:0.39356	validation_1-auc:0.87027	validation_1-logloss:0.43613
# [790]	validation_0-auc:0.90808	validation_0-logloss:0.39299	validation_1-auc:0.87047	validation_1-logloss:0.43579
# [800]	validation_0-auc:0.90859	validation_0-logloss:0.39228	validation_1-auc:0.87065	validation_1-logloss:0.43549
# [810]	validation_0-auc:0.90907	validation_0-logloss:0.39164	validation_1-auc:0.87081	validation_1-logloss:0.43523
# [820]	validation_0-auc:0.90945	validation_0-logloss:0.39108	validation_1-auc:0.87098	validation_1-logloss:0.43501
# [830]	validation_0-auc:0.91003	validation_0-logloss:0.39020	validation_1-auc:0.87128	validation_1-logloss:0.43457
# [840]	validation_0-auc:0.91037	validation_0-logloss:0.38962	validation_1-auc:0.87140	validation_1-logloss:0.43431
# [850]	validation_0-auc:0.91081	validation_0-logloss:0.38899	validation_1-auc:0.87164	validation_1-logloss:0.43395
# [860]	validation_0-auc:0.91139	validation_0-logloss:0.38805	validation_1-auc:0.87201	validation_1-logloss:0.43334
# [870]	validation_0-auc:0.91173	validation_0-logloss:0.38754	validation_1-auc:0.87206	validation_1-logloss:0.43319
# [880]	validation_0-auc:0.91211	validation_0-logloss:0.38693	validation_1-auc:0.87213	validation_1-logloss:0.43300
# [890]	validation_0-auc:0.91248	validation_0-logloss:0.38635	validation_1-auc:0.87227	validation_1-logloss:0.43281
# [900]	validation_0-auc:0.91283	validation_0-logloss:0.38546	validation_1-auc:0.87252	validation_1-logloss:0.43227
# [910]	validation_0-auc:0.91323	validation_0-logloss:0.38485	validation_1-auc:0.87277	validation_1-logloss:0.43192
# [920]	validation_0-auc:0.91365	validation_0-logloss:0.38419	validation_1-auc:0.87292	validation_1-logloss:0.43165
# [930]	validation_0-auc:0.91399	validation_0-logloss:0.38370	validation_1-auc:0.87304	validation_1-logloss:0.43146
# [940]	validation_0-auc:0.91428	validation_0-logloss:0.38318	validation_1-auc:0.87324	validation_1-logloss:0.43115
# [950]	validation_0-auc:0.91462	validation_0-logloss:0.38264	validation_1-auc:0.87337	validation_1-logloss:0.43090
# [960]	validation_0-auc:0.91502	validation_0-logloss:0.38201	validation_1-auc:0.87354	validation_1-logloss:0.43062
# [970]	validation_0-auc:0.91542	validation_0-logloss:0.38141	validation_1-auc:0.87374	validation_1-logloss:0.43033
# [980]	validation_0-auc:0.91580	validation_0-logloss:0.38081	validation_1-auc:0.87391	validation_1-logloss:0.43007
# [990]	validation_0-auc:0.91616	validation_0-logloss:0.38017	validation_1-auc:0.87413	validation_1-logloss:0.42972
# [1000]	validation_0-auc:0.91652	validation_0-logloss:0.37962	validation_1-auc:0.87428	validation_1-logloss:0.42945
# [1010]	validation_0-auc:0.91681	validation_0-logloss:0.37917	validation_1-auc:0.87442	validation_1-logloss:0.42923
# [1020]	validation_0-auc:0.91716	validation_0-logloss:0.37865	validation_1-auc:0.87457	validation_1-logloss:0.42901
# [1030]	validation_0-auc:0.91745	validation_0-logloss:0.37822	validation_1-auc:0.87475	validation_1-logloss:0.42877
# [1040]	validation_0-auc:0.91773	validation_0-logloss:0.37778	validation_1-auc:0.87486	validation_1-logloss:0.42860
# [1050]	validation_0-auc:0.91836	validation_0-logloss:0.37668	validation_1-auc:0.87532	validation_1-logloss:0.42784
# [1060]	validation_0-auc:0.91870	validation_0-logloss:0.37622	validation_1-auc:0.87540	validation_1-logloss:0.42770
# [1070]	validation_0-auc:0.91914	validation_0-logloss:0.37559	validation_1-auc:0.87562	validation_1-logloss:0.42741
# [1080]	validation_0-auc:0.91946	validation_0-logloss:0.37509	validation_1-auc:0.87577	validation_1-logloss:0.42717
# [1090]	validation_0-auc:0.91973	validation_0-logloss:0.37465	validation_1-auc:0.87587	validation_1-logloss:0.42701
# [1100]	validation_0-auc:0.92010	validation_0-logloss:0.37409	validation_1-auc:0.87600	validation_1-logloss:0.42679
# [1110]	validation_0-auc:0.92040	validation_0-logloss:0.37361	validation_1-auc:0.87609	validation_1-logloss:0.42662
# [1120]	validation_0-auc:0.92073	validation_0-logloss:0.37310	validation_1-auc:0.87618	validation_1-logloss:0.42646
# [1130]	validation_0-auc:0.92102	validation_0-logloss:0.37266	validation_1-auc:0.87624	validation_1-logloss:0.42637
# [1140]	validation_0-auc:0.92127	validation_0-logloss:0.37225	validation_1-auc:0.87633	validation_1-logloss:0.42621
# [1150]	validation_0-auc:0.92182	validation_0-logloss:0.37110	validation_1-auc:0.87685	validation_1-logloss:0.42540
# [1160]	validation_0-auc:0.92228	validation_0-logloss:0.37041	validation_1-auc:0.87702	validation_1-logloss:0.42512
# [1170]	validation_0-auc:0.92251	validation_0-logloss:0.37000	validation_1-auc:0.87711	validation_1-logloss:0.42494
# [1180]	validation_0-auc:0.92278	validation_0-logloss:0.36959	validation_1-auc:0.87728	validation_1-logloss:0.42468
# [1190]	validation_0-auc:0.92302	validation_0-logloss:0.36921	validation_1-auc:0.87735	validation_1-logloss:0.42453
# [1200]	validation_0-auc:0.92331	validation_0-logloss:0.36872	validation_1-auc:0.87753	validation_1-logloss:0.42425
# [1210]	validation_0-auc:0.92365	validation_0-logloss:0.36807	validation_1-auc:0.87772	validation_1-logloss:0.42391
# [1220]	validation_0-auc:0.92390	validation_0-logloss:0.36767	validation_1-auc:0.87782	validation_1-logloss:0.42376
# [1230]	validation_0-auc:0.92412	validation_0-logloss:0.36732	validation_1-auc:0.87785	validation_1-logloss:0.42365
# [1240]	validation_0-auc:0.92438	validation_0-logloss:0.36689	validation_1-auc:0.87796	validation_1-logloss:0.42345
# [1250]	validation_0-auc:0.92467	validation_0-logloss:0.36641	validation_1-auc:0.87806	validation_1-logloss:0.42327
# [1260]	validation_0-auc:0.92489	validation_0-logloss:0.36601	validation_1-auc:0.87823	validation_1-logloss:0.42301
# [1270]	validation_0-auc:0.92514	validation_0-logloss:0.36560	validation_1-auc:0.87835	validation_1-logloss:0.42284
# [1280]	validation_0-auc:0.92536	validation_0-logloss:0.36524	validation_1-auc:0.87845	validation_1-logloss:0.42267
# [1290]	validation_0-auc:0.92578	validation_0-logloss:0.36451	validation_1-auc:0.87862	validation_1-logloss:0.42238
# [1300]	validation_0-auc:0.92602	validation_0-logloss:0.36413	validation_1-auc:0.87878	validation_1-logloss:0.42213
# [1310]	validation_0-auc:0.92632	validation_0-logloss:0.36359	validation_1-auc:0.87888	validation_1-logloss:0.42193
# [1320]	validation_0-auc:0.92651	validation_0-logloss:0.36327	validation_1-auc:0.87899	validation_1-logloss:0.42176
# [1330]	validation_0-auc:0.92677	validation_0-logloss:0.36283	validation_1-auc:0.87914	validation_1-logloss:0.42155
# [1340]	validation_0-auc:0.92701	validation_0-logloss:0.36247	validation_1-auc:0.87918	validation_1-logloss:0.42145
# [1350]	validation_0-auc:0.92726	validation_0-logloss:0.36206	validation_1-auc:0.87936	validation_1-logloss:0.42120
# [1360]	validation_0-auc:0.92748	validation_0-logloss:0.36168	validation_1-auc:0.87945	validation_1-logloss:0.42104
# [1370]	validation_0-auc:0.92775	validation_0-logloss:0.36124	validation_1-auc:0.87950	validation_1-logloss:0.42092
# [1380]	validation_0-auc:0.92805	validation_0-logloss:0.36072	validation_1-auc:0.87967	validation_1-logloss:0.42066
# [1390]	validation_0-auc:0.92831	validation_0-logloss:0.36031	validation_1-auc:0.87972	validation_1-logloss:0.42056
# [1400]	validation_0-auc:0.92857	validation_0-logloss:0.35982	validation_1-auc:0.87980	validation_1-logloss:0.42037
# [1410]	validation_0-auc:0.92880	validation_0-logloss:0.35947	validation_1-auc:0.87991	validation_1-logloss:0.42021
# [1420]	validation_0-auc:0.92902	validation_0-logloss:0.35911	validation_1-auc:0.87994	validation_1-logloss:0.42013
# [1430]	validation_0-auc:0.92925	validation_0-logloss:0.35873	validation_1-auc:0.88000	validation_1-logloss:0.41998
# [1440]	validation_0-auc:0.92950	validation_0-logloss:0.35834	validation_1-auc:0.88009	validation_1-logloss:0.41983
# [1450]	validation_0-auc:0.92972	validation_0-logloss:0.35799	validation_1-auc:0.88017	validation_1-logloss:0.41968
# [1460]	validation_0-auc:0.92989	validation_0-logloss:0.35765	validation_1-auc:0.88023	validation_1-logloss:0.41956
# [1470]	validation_0-auc:0.93013	validation_0-logloss:0.35724	validation_1-auc:0.88034	validation_1-logloss:0.41941
# [1480]	validation_0-auc:0.93037	validation_0-logloss:0.35685	validation_1-auc:0.88048	validation_1-logloss:0.41920
# [1490]	validation_0-auc:0.93055	validation_0-logloss:0.35654	validation_1-auc:0.88054	validation_1-logloss:0.41909
# [1500]	validation_0-auc:0.93083	validation_0-logloss:0.35609	validation_1-auc:0.88066	validation_1-logloss:0.41891
# [1510]	validation_0-auc:0.93103	validation_0-logloss:0.35572	validation_1-auc:0.88073	validation_1-logloss:0.41877
# [1520]	validation_0-auc:0.93127	validation_0-logloss:0.35532	validation_1-auc:0.88082	validation_1-logloss:0.41860
# [1530]	validation_0-auc:0.93143	validation_0-logloss:0.35501	validation_1-auc:0.88091	validation_1-logloss:0.41845
# [1540]	validation_0-auc:0.93164	validation_0-logloss:0.35467	validation_1-auc:0.88094	validation_1-logloss:0.41836
# [1550]	validation_0-auc:0.93187	validation_0-logloss:0.35425	validation_1-auc:0.88105	validation_1-logloss:0.41816
# [1560]	validation_0-auc:0.93211	validation_0-logloss:0.35384	validation_1-auc:0.88114	validation_1-logloss:0.41798
# [1570]	validation_0-auc:0.93229	validation_0-logloss:0.35352	validation_1-auc:0.88119	validation_1-logloss:0.41787
# [1580]	validation_0-auc:0.93246	validation_0-logloss:0.35324	validation_1-auc:0.88127	validation_1-logloss:0.41774
# [1590]	validation_0-auc:0.93262	validation_0-logloss:0.35298	validation_1-auc:0.88132	validation_1-logloss:0.41763
# [1600]	validation_0-auc:0.93283	validation_0-logloss:0.35263	validation_1-auc:0.88134	validation_1-logloss:0.41757
# [1610]	validation_0-auc:0.93310	validation_0-logloss:0.35218	validation_1-auc:0.88147	validation_1-logloss:0.41738
# [1620]	validation_0-auc:0.93333	validation_0-logloss:0.35180	validation_1-auc:0.88159	validation_1-logloss:0.41719
# [1630]	validation_0-auc:0.93351	validation_0-logloss:0.35147	validation_1-auc:0.88166	validation_1-logloss:0.41705
# [1640]	validation_0-auc:0.93367	validation_0-logloss:0.35118	validation_1-auc:0.88170	validation_1-logloss:0.41698
# [1650]	validation_0-auc:0.93391	validation_0-logloss:0.35079	validation_1-auc:0.88173	validation_1-logloss:0.41691
# [1660]	validation_0-auc:0.93414	validation_0-logloss:0.35038	validation_1-auc:0.88180	validation_1-logloss:0.41677
# [1670]	validation_0-auc:0.93435	validation_0-logloss:0.35000	validation_1-auc:0.88188	validation_1-logloss:0.41662
# [1680]	validation_0-auc:0.93457	validation_0-logloss:0.34959	validation_1-auc:0.88194	validation_1-logloss:0.41647
# [1690]	validation_0-auc:0.93475	validation_0-logloss:0.34929	validation_1-auc:0.88201	validation_1-logloss:0.41634
# [1700]	validation_0-auc:0.93494	validation_0-logloss:0.34896	validation_1-auc:0.88208	validation_1-logloss:0.41624
# [1710]	validation_0-auc:0.93515	validation_0-logloss:0.34861	validation_1-auc:0.88216	validation_1-logloss:0.41610
# [1720]	validation_0-auc:0.93534	validation_0-logloss:0.34829	validation_1-auc:0.88221	validation_1-logloss:0.41602
# [1730]	validation_0-auc:0.93556	validation_0-logloss:0.34793	validation_1-auc:0.88220	validation_1-logloss:0.41598
# [1740]	validation_0-auc:0.93572	validation_0-logloss:0.34761	validation_1-auc:0.88233	validation_1-logloss:0.41579
# [1750]	validation_0-auc:0.93590	validation_0-logloss:0.34729	validation_1-auc:0.88237	validation_1-logloss:0.41570
# [1760]	validation_0-auc:0.93608	validation_0-logloss:0.34697	validation_1-auc:0.88244	validation_1-logloss:0.41558
# [1770]	validation_0-auc:0.93626	validation_0-logloss:0.34666	validation_1-auc:0.88252	validation_1-logloss:0.41544
# [1780]	validation_0-auc:0.93643	validation_0-logloss:0.34634	validation_1-auc:0.88258	validation_1-logloss:0.41531
# [1790]	validation_0-auc:0.93663	validation_0-logloss:0.34598	validation_1-auc:0.88265	validation_1-logloss:0.41520
# [1800]	validation_0-auc:0.93685	validation_0-logloss:0.34565	validation_1-auc:0.88271	validation_1-logloss:0.41510
# [1810]	validation_0-auc:0.93709	validation_0-logloss:0.34526	validation_1-auc:0.88284	validation_1-logloss:0.41491
# [1820]	validation_0-auc:0.93726	validation_0-logloss:0.34496	validation_1-auc:0.88289	validation_1-logloss:0.41480
# [1830]	validation_0-auc:0.93744	validation_0-logloss:0.34462	validation_1-auc:0.88299	validation_1-logloss:0.41462
# [1840]	validation_0-auc:0.93780	validation_0-logloss:0.34396	validation_1-auc:0.88326	validation_1-logloss:0.41420
# [1850]	validation_0-auc:0.93798	validation_0-logloss:0.34360	validation_1-auc:0.88334	validation_1-logloss:0.41407
# [1860]	validation_0-auc:0.93812	validation_0-logloss:0.34335	validation_1-auc:0.88338	validation_1-logloss:0.41398
# [1870]	validation_0-auc:0.93831	validation_0-logloss:0.34300	validation_1-auc:0.88348	validation_1-logloss:0.41382
# [1880]	validation_0-auc:0.93854	validation_0-logloss:0.34259	validation_1-auc:0.88354	validation_1-logloss:0.41370
# [1890]	validation_0-auc:0.93873	validation_0-logloss:0.34212	validation_1-auc:0.88373	validation_1-logloss:0.41336
# [1900]	validation_0-auc:0.93895	validation_0-logloss:0.34165	validation_1-auc:0.88395	validation_1-logloss:0.41302
# [1910]	validation_0-auc:0.93920	validation_0-logloss:0.34120	validation_1-auc:0.88402	validation_1-logloss:0.41289
# [1920]	validation_0-auc:0.93947	validation_0-logloss:0.34071	validation_1-auc:0.88408	validation_1-logloss:0.41275
# [1930]	validation_0-auc:0.93965	validation_0-logloss:0.34038	validation_1-auc:0.88408	validation_1-logloss:0.41270
# [1940]	validation_0-auc:0.93981	validation_0-logloss:0.34008	validation_1-auc:0.88410	validation_1-logloss:0.41264
# [1950]	validation_0-auc:0.93997	validation_0-logloss:0.33979	validation_1-auc:0.88415	validation_1-logloss:0.41253
# [1960]	validation_0-auc:0.94015	validation_0-logloss:0.33947	validation_1-auc:0.88416	validation_1-logloss:0.41247
# [1970]	validation_0-auc:0.94029	validation_0-logloss:0.33923	validation_1-auc:0.88417	validation_1-logloss:0.41241
# [1980]	validation_0-auc:0.94049	validation_0-logloss:0.33890	validation_1-auc:0.88420	validation_1-logloss:0.41236
# [1990]	validation_0-auc:0.94069	validation_0-logloss:0.33858	validation_1-auc:0.88429	validation_1-logloss:0.41224
# [2000]	validation_0-auc:0.94084	validation_0-logloss:0.33829	validation_1-auc:0.88434	validation_1-logloss:0.41214
# [2010]	validation_0-auc:0.94098	validation_0-logloss:0.33802	validation_1-auc:0.88437	validation_1-logloss:0.41205
# [2020]	validation_0-auc:0.94118	validation_0-logloss:0.33762	validation_1-auc:0.88456	validation_1-logloss:0.41178
# [2030]	validation_0-auc:0.94134	validation_0-logloss:0.33734	validation_1-auc:0.88460	validation_1-logloss:0.41169
# [2040]	validation_0-auc:0.94147	validation_0-logloss:0.33709	validation_1-auc:0.88465	validation_1-logloss:0.41160
# [2050]	validation_0-auc:0.94161	validation_0-logloss:0.33684	validation_1-auc:0.88475	validation_1-logloss:0.41146
# [2060]	validation_0-auc:0.94178	validation_0-logloss:0.33657	validation_1-auc:0.88483	validation_1-logloss:0.41134
# [2070]	validation_0-auc:0.94195	validation_0-logloss:0.33625	validation_1-auc:0.88487	validation_1-logloss:0.41126
# [2080]	validation_0-auc:0.94212	validation_0-logloss:0.33596	validation_1-auc:0.88493	validation_1-logloss:0.41116
# [2090]	validation_0-auc:0.94230	validation_0-logloss:0.33562	validation_1-auc:0.88499	validation_1-logloss:0.41104
# [2100]	validation_0-auc:0.94251	validation_0-logloss:0.33513	validation_1-auc:0.88513	validation_1-logloss:0.41078
# [2110]	validation_0-auc:0.94270	validation_0-logloss:0.33478	validation_1-auc:0.88522	validation_1-logloss:0.41062
# [2120]	validation_0-auc:0.94287	validation_0-logloss:0.33444	validation_1-auc:0.88526	validation_1-logloss:0.41052
# [2130]	validation_0-auc:0.94301	validation_0-logloss:0.33420	validation_1-auc:0.88528	validation_1-logloss:0.41047
# [2140]	validation_0-auc:0.94315	validation_0-logloss:0.33390	validation_1-auc:0.88533	validation_1-logloss:0.41036
# [2150]	validation_0-auc:0.94327	validation_0-logloss:0.33366	validation_1-auc:0.88539	validation_1-logloss:0.41026
# [2160]	validation_0-auc:0.94344	validation_0-logloss:0.33331	validation_1-auc:0.88544	validation_1-logloss:0.41017
# [2170]	validation_0-auc:0.94358	validation_0-logloss:0.33304	validation_1-auc:0.88549	validation_1-logloss:0.41008
# [2180]	validation_0-auc:0.94378	validation_0-logloss:0.33251	validation_1-auc:0.88563	validation_1-logloss:0.40980
# [2190]	validation_0-auc:0.94397	validation_0-logloss:0.33214	validation_1-auc:0.88569	validation_1-logloss:0.40968
# [2200]	validation_0-auc:0.94414	validation_0-logloss:0.33143	validation_1-auc:0.88587	validation_1-logloss:0.40926
# [2210]	validation_0-auc:0.94432	validation_0-logloss:0.33112	validation_1-auc:0.88590	validation_1-logloss:0.40917
# [2220]	validation_0-auc:0.94444	validation_0-logloss:0.33090	validation_1-auc:0.88593	validation_1-logloss:0.40911
# [2230]	validation_0-auc:0.94460	validation_0-logloss:0.33059	validation_1-auc:0.88597	validation_1-logloss:0.40902
# [2240]	validation_0-auc:0.94478	validation_0-logloss:0.33026	validation_1-auc:0.88609	validation_1-logloss:0.40886
# [2250]	validation_0-auc:0.94494	validation_0-logloss:0.32995	validation_1-auc:0.88613	validation_1-logloss:0.40876
# [2260]	validation_0-auc:0.94511	validation_0-logloss:0.32962	validation_1-auc:0.88621	validation_1-logloss:0.40863
# [2270]	validation_0-auc:0.94524	validation_0-logloss:0.32940	validation_1-auc:0.88624	validation_1-logloss:0.40857
# [2280]	validation_0-auc:0.94540	validation_0-logloss:0.32909	validation_1-auc:0.88629	validation_1-logloss:0.40848
# [2290]	validation_0-auc:0.94556	validation_0-logloss:0.32878	validation_1-auc:0.88633	validation_1-logloss:0.40839
# [2300]	validation_0-auc:0.94571	validation_0-logloss:0.32849	validation_1-auc:0.88634	validation_1-logloss:0.40835
# [2310]	validation_0-auc:0.94584	validation_0-logloss:0.32826	validation_1-auc:0.88639	validation_1-logloss:0.40826
# [2320]	validation_0-auc:0.94593	validation_0-logloss:0.32806	validation_1-auc:0.88643	validation_1-logloss:0.40817
# [2330]	validation_0-auc:0.94612	validation_0-logloss:0.32770	validation_1-auc:0.88654	validation_1-logloss:0.40798
# [2340]	validation_0-auc:0.94627	validation_0-logloss:0.32743	validation_1-auc:0.88655	validation_1-logloss:0.40794
# [2350]	validation_0-auc:0.94643	validation_0-logloss:0.32714	validation_1-auc:0.88657	validation_1-logloss:0.40790
# [2360]	validation_0-auc:0.94655	validation_0-logloss:0.32689	validation_1-auc:0.88658	validation_1-logloss:0.40785
# [2370]	validation_0-auc:0.94669	validation_0-logloss:0.32663	validation_1-auc:0.88662	validation_1-logloss:0.40779
# [2380]	validation_0-auc:0.94684	validation_0-logloss:0.32631	validation_1-auc:0.88670	validation_1-logloss:0.40764
# [2390]	validation_0-auc:0.94703	validation_0-logloss:0.32596	validation_1-auc:0.88675	validation_1-logloss:0.40756
# [2400]	validation_0-auc:0.94717	validation_0-logloss:0.32559	validation_1-auc:0.88686	validation_1-logloss:0.40733
# [2410]	validation_0-auc:0.94731	validation_0-logloss:0.32530	validation_1-auc:0.88691	validation_1-logloss:0.40722
# [2420]	validation_0-auc:0.94748	validation_0-logloss:0.32500	validation_1-auc:0.88703	validation_1-logloss:0.40706
# [2430]	validation_0-auc:0.94759	validation_0-logloss:0.32478	validation_1-auc:0.88707	validation_1-logloss:0.40699
# [2440]	validation_0-auc:0.94772	validation_0-logloss:0.32453	validation_1-auc:0.88709	validation_1-logloss:0.40694
# [2450]	validation_0-auc:0.94787	validation_0-logloss:0.32425	validation_1-auc:0.88714	validation_1-logloss:0.40687
# [2460]	validation_0-auc:0.94798	validation_0-logloss:0.32401	validation_1-auc:0.88718	validation_1-logloss:0.40679
# [2470]	validation_0-auc:0.94813	validation_0-logloss:0.32373	validation_1-auc:0.88721	validation_1-logloss:0.40673
# [2480]	validation_0-auc:0.94824	validation_0-logloss:0.32352	validation_1-auc:0.88720	validation_1-logloss:0.40670
# [2490]	validation_0-auc:0.94839	validation_0-logloss:0.32325	validation_1-auc:0.88727	validation_1-logloss:0.40660
# [2500]	validation_0-auc:0.94852	validation_0-logloss:0.32298	validation_1-auc:0.88733	validation_1-logloss:0.40647
# [2510]	validation_0-auc:0.94864	validation_0-logloss:0.32274	validation_1-auc:0.88737	validation_1-logloss:0.40640
# [2520]	validation_0-auc:0.94876	validation_0-logloss:0.32251	validation_1-auc:0.88740	validation_1-logloss:0.40634
# [2530]	validation_0-auc:0.94887	validation_0-logloss:0.32226	validation_1-auc:0.88744	validation_1-logloss:0.40626
# [2540]	validation_0-auc:0.94902	validation_0-logloss:0.32196	validation_1-auc:0.88749	validation_1-logloss:0.40616
# [2550]	validation_0-auc:0.94916	validation_0-logloss:0.32167	validation_1-auc:0.88754	validation_1-logloss:0.40606
# [2560]	validation_0-auc:0.94927	validation_0-logloss:0.32145	validation_1-auc:0.88757	validation_1-logloss:0.40600
# [2570]	validation_0-auc:0.94938	validation_0-logloss:0.32124	validation_1-auc:0.88757	validation_1-logloss:0.40597
# [2580]	validation_0-auc:0.94949	validation_0-logloss:0.32100	validation_1-auc:0.88762	validation_1-logloss:0.40586
# [2590]	validation_0-auc:0.94963	validation_0-logloss:0.32074	validation_1-auc:0.88763	validation_1-logloss:0.40581
# [2600]	validation_0-auc:0.94976	validation_0-logloss:0.32049	validation_1-auc:0.88766	validation_1-logloss:0.40576
# [2610]	validation_0-auc:0.94990	validation_0-logloss:0.32020	validation_1-auc:0.88764	validation_1-logloss:0.40575
# Stopping. Best iteration:
# [2602]	validation_0-auc:0.94978	validation_0-logloss:0.32044	validation_1-auc:0.88767	validation_1-logloss:0.40574
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=10000, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#               validate_parameters=False, verbosity=None)

# %% [markdown]
# ## Plot

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

results = xgb_model.evals_result()
epochs = len(results['validation_0']['logloss'])
x_axis = range(0, epochs)

fig = plt.figure(figsize=(20,6))

# plot log loss
ax = fig.add_subplot(121)
ax.plot(x_axis, results['validation_0']['logloss'], label='Train')
ax.plot(x_axis, results['validation_1']['logloss'], label='Test')
ax.legend()
ax.set_ylabel('Log Loss')
ax.set_title('XGBoost Log Loss')

# plot classification AUC
ax = fig.add_subplot(122)
ax.plot(x_axis, results['validation_0']['auc'], label='Train')
ax.plot(x_axis, results['validation_1']['auc'], label='Test')
ax.legend()
ax.set_ylabel('Classification AUC')
ax.set_title('XGBoost Classification AUC')
plt.show()

# %% [markdown]
# ### Save the model

# %%
from datetime import datetime

# %%
now = datetime.now().strftime("%d.%m_%H.%M")
xgb_model.save_model('models/model_{}.dat'.format(now))

# %% [markdown]
# ### GridSearch

# %%
# from sklearn.model_selection import GridSearchCV

# parameters = {'nthread':[4], 
#               'objective':['binary:logistic'],
#               'learning_rate': [0.1,0.5,1], 
#               'max_depth': [3,5],
#               'scale_pos_weight':[1,5,20],
#               'min_child_weight': [4,5],
#               'silent': [1],
#               'subsample': [0.7],
#               'colsample_bytree': [0.7, 0.9],
#               'n_estimators': [50]}

# N = 100
# xgb_model = xgb.XGBClassifier(n_estimators=N)
# grid = GridSearchCV(xgb_model, parameters,
#                     n_jobs = 5, scoring='roc_auc',
#                     verbose=True)
# grid.fit(X_tr_q1q2, y_train)

# %% [markdown]
# ### Mistakes

# %%
def get_mistakes(clf, X_q1q2, y):

    predictions = np.around(clf.predict(X_q1q2)).astype(int)   
#     print(y[:10])
#     print(predictions[:10])
    incorrect_predictions = predictions!=y
#     print(incorrect_predictions[:10])
#     print(np.where(incorrect_predictions)[:10])
    incorrect_indices = np.where(incorrect_predictions)[0]
    
    if np.sum(incorrect_predictions)==0:
        print("no mistakes in this df")
    else:
        return incorrect_indices, predictions
    
def print_mistake_k(k, mistake_indices, predictions, df):
    print(df.iloc[mistake_indices[k]].question1)
    print(df.iloc[mistake_indices[k]].question2)
    print("true class:", df.iloc[mistake_indices[k]].is_duplicate)
    print("prediction:", predictions[mistake_indices[k]])
    
def print_mistake_k_and_tokens(k, mistake_indices, predictions,
                               X_q1q2, count_vect, clf, df):
    q1 = df.iloc[mistake_indices[k]].question1
    q2 = df.iloc[mistake_indices[k]].question2
    
    print(q1)
    print(count_vect.tokenize(q1))
    print()
    print(q2)
    print(count_vect.tokenize(q2))
    print()
    print("true class:", df.iloc[mistake_indices[k]].is_duplicate)
    print("prediction:", predictions[mistake_indices[k]])
    print()
    print("Probability vector: [P(0|x), P(1|x)]:")
    print(clf.predict_proba(X_q1q2)[mistake_indices[k],:])
    
    
def hist_errors(mistake_indices, predictions,
                               X_q1q2, count_vect, clf, df):
    qs = df.iloc[mistake_indices][['question1', 'question2']]
    qs['true_class']=df.iloc[mistake_indices].is_duplicate
    qs['prediction']=predictions[mistake_indices]
    qs['P(1|x)']=clf.predict_proba(X_q1q2)[mistake_indices,:][:,1]
    qs = qs.reset_index(drop=True)
    return qs

# %%
mistake_indices, predictions = get_mistakes(xgb_model, X_te_q1q2, y_test)

# %% [markdown]
# ### Load the model

# %%
# now =

# %%
bst = xgb.Booster({'nthread': 4})  # init booster
bst.load_model('models/model_{}.dat'.format(now))  # load data

# %%
xgb_loaded_model = xgb.XGBClassifier()
xgb_loaded_model._Booster=bst

# %%
mistake_indices, predictions = get_mistakes(xgb_loaded_model, X_te_q1q2, y_test)
# Out:
# /opt/anaconda/lib/python3.6/site-packages/xgboost/sklearn.py:901: UserWarning: Label encoder is not defined.  Returning class probability.
#   'Label encoder is not defined.  Returning class probability.')

# %%
len(mistake_indices)
# Out:
# 15425

# %%
print_mistake_k(0, mistake_indices, predictions, test_df)
# Out:
# How can one open a demat account?
# How do I open a demat account?
# true class: 1
# prediction: 0

# %%
print_mistake_k_and_tokens(0, mistake_indices, predictions,
                           X_te_q1q2, count_vect, xgb_loaded_model, test_df)
# Out:
# How can one open a demat account?
# ['how', 'can', 'one', 'open', 'a', 'demat', 'account', 'how', 'eighttokens', ('how', 'can'), ('can', 'one'), ('one', 'open'), ('open', 'a'), ('a', 'demat'), ('demat', 'account'), ('account', 'how'), ('how', 'can', 'one'), ('can', 'one', 'open'), ('one', 'open', 'a'), ('open', 'a', 'demat'), ('a', 'demat', 'account'), ('demat', 'account', 'how')]
#
# How do I open a demat account?
# ['how', 'do', 'i', 'open', 'a', 'demat', 'account', 'how', 'eighttokens', ('how', 'do'), ('do', 'i'), ('i', 'open'), ('open', 'a'), ('a', 'demat'), ('demat', 'account'), ('account', 'how'), ('how', 'do', 'i'), ('do', 'i', 'open'), ('i', 'open', 'a'), ('open', 'a', 'demat'), ('a', 'demat', 'account'), ('demat', 'account', 'how')]
#
# true class: 1
# prediction: 0
#
# Probability vector: [P(0|x), P(1|x)]:
# [0.5170665  0.48293355]

# %%
qs = hist_errors(mistake_indices, predictions,
                           X_te_q1q2, count_vect, xgb_loaded_model, test_df)

# %%
N = 20

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

pd.set_option('display.max_rows', N)
pd.set_option('display.max_colwidth', -1)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Read mistakes
qs.head(N)
# Out:
#                                                                          question1  \
# 0   How can one open a demat account?
# 1   Which book is the best for GRE preparation?
# 2   How can an Indian student get into Harvard Medical School for their undergrad?
# 3   What is the purpose of solubility tests?
# 4   Why am I getting my period so much?
# 5   Is Purina good for dogs?
# 6   How can I recover an iPhone 5 deleted text conversation?
# 7   What are the best resources to learn exploratory data analysis?
# 8   What makes a woman attractive?
# 9   Is there any way to adjust title and font default settings in Google docs?
# 10  What are the key cultural differences between China and Japan?
# 11  Why can't I control my anger? What can I do about it?
# 12  How many articles does the Constitution have?
# 13  How do know that you are in love?
# 14  Is LinkedIn a good acquisition for Microsoft?
# 15  What is a limbo?
# 16  How can one get a patent?
# 17  What business can I start that won’t require my presence to operate?
# 18  What should I learn before joining CA articleship?
# 19  What is the life of an IES officer?
#
#                                                                                                     question2  \
# 0   How do I open a demat account?
# 1   Which are the best books for the IELTS and the GRE preparation?
# 2   What do I need to do to get into Harvard Medical School?
# 3   Why do you do the solubility test?
# 4   Why am I getting my period twice a month?
# 5   How is Purina Puppy Chow good for dogs?
# 6   How do I retrieve my deleted SMS from iPhone 6?
# 7   What are the best resources for exploratory data analysis?
# 8   What makes an Indian girl more beautiful?
# 9   How can I change the default font in Google docs?
# 10  What do you think is the biggest cultural difference between Canada and China?
# 11  How can I control my anger?
# 12  How many articles and chapter are their in our Indian constitution?
# 13  How do you know you are not in love?
# 14  Will Microsoft's acquisition of LinkedIn prove useful for Microsoft? If so, what will 'useful' look like?
# 15  What is actually a limbo?
# 16  Can I get patent for a simple idea?
# 17  What can I do to support and encourage the development of synthetic meat?
# 18  What skills should a CA student develop before starting articleship?
# 19  What is the lifestyle of an IAS officer?
#
#     true_class  prediction    P(1|x)
# 0   1           0           0.482934
# 1   0           1           0.506529
# 2   0           1           0.814704
# 3   1           0           0.031142
# 4   0           1           0.597886
# 5   1           0           0.473904
# 6   1           0           0.356761
# 7   1           0           0.318633
# 8   0           1           0.518331
# 9   1           0           0.131091
# 10  0           1           0.573090
# 11  0           1           0.781049
# 12  1           0           0.364232
# 13  0           1           0.508101
# 14  1           0           0.406709
# 15  1           0           0.339713
# 16  0           1           0.748282
# 17  0           1           0.643806
# 18  1           0           0.352385
# 19  1           0           0.329825

# %% [markdown]
# # TFIDF

# %%
tfidf_vectorizer = TFIDFVectorizer(count_vect.vocabulary, count_vect.word_to_ind, count_vect.tokenize)
tfidf_vectorizer.fit(all_questions)
# Out:
# TFIDF fit finished in 181.48 seconds

# %%
X_tfidf_tr_q1q2 = get_features_from_df(train_df, tfidf_vectorizer)
X_tfidf_te_q1q2  = get_features_from_df(test_df, tfidf_vectorizer)

X_tfidf_tr_q1q2.shape, train_df.shape, test_df.shape, X_tfidf_te_q1q2.shape
# Out:
# TFIDF transform finished in 91.75 seconds
# TFIDF transform finished in 93.02 seconds
# TFIDF transform finished in 22.81 seconds
# TFIDF transform finished in 23.93 seconds
# ((323432, 6166022), (323432, 6), (80858, 6), (80858, 6166022))

# %%
logistic = sklearn.linear_model.LogisticRegression(solver="liblinear", verbose=1, max_iter=100)
logistic.fit(X_tfidf_tr_q1q2, y_train)
# Out:
# [LibLinear]
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=1,
#                    warm_start=False)

# %%
logistic.score(X_tfidf_tr_q1q2, y_train), logistic.score(X_tfidf_te_q1q2, y_test)
# Out:
# (0.9006499047713276, 0.7898167157238616)

# %%
mistake_indices, predictions = get_mistakes(logistic, X_tfidf_te_q1q2, y_test)

# %%
print_mistake_k(0, mistake_indices, predictions)
# Out:
# How do I study for Honeywell company recruitment?
# How do I study for Honeywell company recruitments?
# true class: 1
# prediction: 0

# %%
print_mistake_k_and_tokens(0, mistake_indices, predictions,
                           X_tfidf_te_q1q2, tfidf_vectorizer, logistic)
# Out:
# How do I study for Honeywell company recruitment?
# ['how', 'do', 'i', 'studi', 'for', 'honeywel', 'compani', 'recruit', ('how', 'do'), ('do', 'i'), ('i', 'studi'), ('studi', 'for'), ('for', 'honeywel'), ('honeywel', 'compani'), ('compani', 'recruit'), ('how', 'do', 'i'), ('do', 'i', 'studi'), ('i', 'studi', 'for'), ('studi', 'for', 'honeywel'), ('for', 'honeywel', 'compani'), ('honeywel', 'compani', 'recruit')]
#
# How do I study for Honeywell company recruitments?
# ['how', 'do', 'i', 'studi', 'for', 'honeywel', 'compani', 'recruit', ('how', 'do'), ('do', 'i'), ('i', 'studi'), ('studi', 'for'), ('for', 'honeywel'), ('honeywel', 'compani'), ('compani', 'recruit'), ('how', 'do', 'i'), ('do', 'i', 'studi'), ('i', 'studi', 'for'), ('studi', 'for', 'honeywel'), ('for', 'honeywel', 'compani'), ('honeywel', 'compani', 'recruit')]
#
# true class: 1
# prediction: 0
#
# Probability vector: [P(0|x), P(1|x)]:
# [0.73466044 0.26533956]

# %%
######### SEARCH QUESTIONS WITH SAME TOKENS ###########

q1_casted =  cast_list_as_strings(list(train_df["question1"]))
q2_casted =  cast_list_as_strings(list(train_df["question2"]))

q1 = count_vect.transform(q1_casted)
q2 = count_vect.transform(q2_casted)

same_tokens_idxs = []
for i in range(len(q1_casted)):
    same_features = ( q1[i] != q2[i] ).nnz == 0
    if same_features:
        same_tokens_idxs.append(i)
    if i % 500 == 0: print(i)

same_tokens_idxs = np.array(same_tokens_idxs)


same_tokens = train_df.iloc[same_tokens_idxs]
duplicates = same_tokens['is_duplicate'] == 1
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000
# 11500
# 12000
# 12500
# 13000
# 13500
# 14000
# 14500
# 15000
# 15500
# 16000
# 16500
# 17000
# 17500
# 18000
# 18500
# 19000
# 19500
# 20000
# 20500
# 21000
# 21500
# 22000
# 22500
# 23000
# 23500
# 24000
# 24500
# 25000
# 25500
# 26000
# 26500
# 27000
# 27500
# 28000
# 28500
# 29000
# 29500
# 30000
# 30500
# 31000
# 31500
# 32000
# 32500
# 33000
# 33500
# 34000
# 34500
# 35000
# 35500
# 36000
# 36500
# 37000
# 37500
# 38000
# 38500
# 39000
# 39500
# 40000
# 40500
# 41000
# 41500
# 42000
# 42500
# 43000
# 43500
# 44000
# 44500
# 45000
# 45500
# 46000
# 46500
# 47000
# 47500
# 48000
# 48500
# 49000
# 49500
# 50000
# 50500
# 51000
# 51500
# 52000
# 52500
# 53000
# 53500
# 54000
# 54500
# 55000
# 55500
# 56000
# 56500
# 57000
# 57500
# 58000
# 58500
# 59000
# 59500
# 60000
# 60500
# 61000
# 61500
# 62000
# 62500
# 63000
# 63500
# 64000
# 64500
# 65000
# 65500
# 66000
# 66500
# 67000
# 67500
# 68000
# 68500
# 69000
# 69500
# 70000
# 70500
# 71000
# 71500
# 72000
# 72500
# 73000
# 73500
# 74000
# 74500
# 75000
# 75500
# 76000
# 76500
# 77000
# 77500
# 78000
# 78500
# 79000
# 79500
# 80000
# 80500
# 81000
# 81500
# 82000
# 82500
# 83000
# 83500
# 84000
# 84500
# 85000
# 85500
# 86000
# 86500
# 87000
# 87500
# 88000
# 88500
# 89000
# 89500
# 90000
# 90500
# 91000
# 91500
# 92000
# 92500
# 93000
# 93500
# 94000
# 94500
# 95000
# 95500
# 96000
# 96500
# 97000
# 97500
# 98000
# 98500
# 99000
# 99500
# 100000
# 100500
# 101000
# 101500
# 102000
# 102500
# 103000
# 103500
# 104000
# 104500
# 105000
# 105500
# 106000
# 106500
# 107000
# 107500
# 108000
# 108500
# 109000
# 109500
# 110000
# 110500
# 111000
# 111500
# 112000
# 112500
# 113000
# 113500
# 114000
# 114500
# 115000
# 115500
# 116000
# 116500
# 117000
# 117500
# 118000
# 118500
# 119000
# 119500
# 120000
# 120500
# 121000
# 121500
# 122000
# 122500
# 123000
# 123500
# 124000
# 124500
# 125000
# 125500
# 126000
# 126500
# 127000
# 127500
# 128000
# 128500
# 129000
# 129500
# 130000
# 130500
# 131000
# 131500
# 132000
# 132500
# 133000
# 133500
# 134000
# 134500
# 135000
# 135500
# 136000
# 136500
# 137000
# 137500
# 138000
# 138500
# 139000
# 139500
# 140000
# 140500
# 141000
# 141500
# 142000
# 142500
# 143000
# 143500
# 144000
# 144500
# 145000
# 145500
# 146000
# 146500
# 147000
# 147500
# 148000
# 148500
# 149000
# 149500
# 150000
# 150500
# 151000
# 151500
# 152000
# 152500
# 153000
# 153500
# 154000
# 154500
# 155000
# 155500
# 156000
# 156500
# 157000
# 157500
# 158000
# 158500
# 159000
# 159500
# 160000
# 160500
# 161000
# 161500
# 162000
# 162500
# 163000
# 163500
# 164000
# 164500
# 165000
# 165500
# 166000
# 166500
# 167000
# 167500
# 168000
# 168500
# 169000
# 169500
# 170000
# 170500
# 171000
# 171500
# 172000
# 172500
# 173000
# 173500
# 174000
# 174500
# 175000
# 175500
# 176000
# 176500
# 177000
# 177500
# 178000
# 178500
# 179000
# 179500
# 180000
# 180500
# 181000
# 181500
# 182000
# 182500
# 183000
# 183500
# 184000
# 184500
# 185000
# 185500
# 186000
# 186500
# 187000
# 187500
# 188000
# 188500
# 189000
# 189500
# 190000
# 190500
# 191000
# 191500
# 192000
# 192500
# 193000
# 193500
# 194000
# 194500
# 195000
# 195500
# 196000
# 196500
# 197000
# 197500
# 198000
# 198500
# 199000
# 199500
# 200000
# 200500
# 201000
# 201500
# 202000
# 202500
# 203000
# 203500
# 204000
# 204500
# 205000
# 205500
# 206000
# 206500
# 207000
# 207500
# 208000
# 208500
# 209000
# 209500
# 210000
# 210500
# 211000
# 211500
# 212000
# 212500
# 213000
# 213500
# 214000
# 214500
# 215000
# 215500
# 216000
# 216500
# 217000
# 217500
# 218000
# 218500
# 219000
# 219500
# 220000
# 220500
# 221000
# 221500
# 222000
# 222500
# 223000
# 223500
# 224000
# 224500
# 225000
# 225500
# 226000
# 226500
# 227000
# 227500
# 228000
# 228500
# 229000
# 229500
# 230000
# 230500
# 231000
# 231500
# 232000
# 232500
# 233000
# 233500
# 234000
# 234500
# 235000
# 235500
# 236000
# 236500
# 237000
# 237500
# 238000
# 238500
# 239000
# 239500
# 240000
# 240500
# 241000
# 241500
# 242000
# 242500
# 243000
# 243500
# 244000
# 244500
# 245000
# 245500
# 246000
# 246500
# 247000
# 247500
# 248000
# 248500
# 249000
# 249500
# 250000
# 250500
# 251000
# 251500
# 252000
# 252500
# 253000
# 253500
# 254000
# 254500
# 255000
# 255500
# 256000
# 256500
# 257000
# 257500
# 258000
# 258500
# 259000
# 259500
# 260000
# 260500
# 261000
# 261500
# 262000
# 262500
# 263000
# 263500
# 264000
# 264500
# 265000
# 265500
# 266000
# 266500
# 267000
# 267500
# 268000
# 268500
# 269000
# 269500
# 270000
# 270500
# 271000
# 271500
# 272000
# 272500
# 273000
# 273500
# 274000
# 274500
# 275000
# 275500
# 276000
# 276500
# 277000
# 277500
# 278000
# 278500
# 279000
# 279500
# 280000
# 280500
# 281000
# 281500
# 282000
# 282500
# 283000
# 283500
# 284000
# 284500
# 285000
# 285500
# 286000
# 286500
# 287000
# 287500
# 288000
# 288500
# 289000
# 289500
# 290000
# 290500
# 291000
# 291500
# 292000
# 292500
# 293000
# 293500
# 294000
# 294500
# 295000
# 295500
# 296000
# 296500
# 297000
# 297500
# 298000
# 298500
# 299000
# 299500
# 300000
# 300500
# 301000
# 301500
# 302000
# 302500
# 303000
# 303500
# 304000
# 304500
# 305000
# 305500
# 306000
# 306500
# 307000
# 307500
# 308000
# 308500
# 309000
# 309500
# 310000
# 310500
# 311000
# 311500
# 312000
# 312500
# 313000
# 313500
# 314000
# 314500
# 315000
# 315500
# 316000
# 316500
# 317000
# 317500
# 318000
# 318500
# 319000
# 319500
# 320000
# 320500
# 321000
# 321500
# 322000
# 322500
# 323000
#             id    qid1    qid2  \
# 154       3148    6241    6242
# 170      15678   29935   29936
# 246     403514  253677  537096
# 1723    290549   26661   70364
# 2145    184520  281899  281900
# ...        ...     ...     ...
# 316104   45535   81584   81585
# 316373  288872  294219  122887
# 317754  248848  285169  362342
# 318279  102122  169021  169022
# 319355  273876  392410  392411
#
#                                                 question1  \
# 154            How do I overcome my inferiority complex ?
# 170                How can I make money as a 13 year old?
# 246            What are the most haunted places in delhi?
# 1723    What language is used in Visual Basic? How doe...
# 2145             What are the best things about modeling?
# ...                                                   ...
# 316104                    What is the definition of blog?
# 316373           What is the difference between : and ; ?
# 317754                        What does this symbol mean?
# 318279                               What is refrigerant?
# 319355                                    What is Timing?
#
#                                                 question2  is_duplicate
# 154             How do I overcome my inferiority complex?             0
# 170          How can I make money as a thirteen year old?             0
# 246             What are the most haunted place in delhi?             0
# 1723    What language is used in Visual Basic? How doe...             0
# 2145               What are the best things about models?             0
# ...                                                   ...           ...
# 316104                What is the definition of blogging?             0
# 316373    What is the difference between ":=" and "::=" ?             0
# 317754                    What does this '≜' symbol mean?             0
# 318279                             What is refrigeration?             0
# 319355                                     What is timee?             0
#
# [230 rows x 6 columns]

# %%
same_tokens[duplicates]
# Out:
#             id    qid1    qid2  \
# 1       327668  454117  345117
# 163     251786  317853   86925
# 873     351007  479805  479806
# 1644    383603  474670   70140
# 1857    346791  421809  140365
# ...        ...     ...     ...
# 322629  302747  425769  425770
# 322814  272376  390622  390623
# 322882  115624  188516  188517
# 323043  256986  372216  372217
# 323320   76582  130894  130895
#
#                                                 question1  \
# 1       How do I study for Honeywell company recruitment?
# 163      How do I get permanent residence in New Zealand?
# 873                       What is Open source technology?
# 1644               Who will be the next president of US ?
# 1857       What are some examples of vertebrated animals?
# ...                                                   ...
# 322629      How is the word 'servile' used in a sentence?
# 322814  Is there any good reading room available near ...
# 322882  Two hot copper and steel balls long sitting in...
# 323043                  Do virus and Bacteria have souls?
# 323320  What's the best website in which I can take up...
#
#                                                 question2  is_duplicate
# 1       How do I study for Honeywell company recruitme...             1
# 163      How do I get permanent residency in New Zealand?             1
# 873                     What is open source technologies?             1
# 1644                Who will be the next president of US?             1
# 1857        What are some examples of vertebrate animals?             1
# ...                                                   ...           ...
# 322629      How is the word "servile" used in a sentence?             1
# 322814  Is there any good reading room available near ...             1
# 322882  Two hot copper and steel balls long sitting in...             1
# 323043                Do viruses and bacteria have souls?             1
# 323320  Whats the best website in which I can take up ...             1
#
# [1342 rows x 6 columns]

# %%
same_tokens[~duplicates]
# Out:
#             id    qid1    qid2  \
# 154       3148    6241    6242
# 170      15678   29935   29936
# 246     403514  253677  537096
# 1723    290549   26661   70364
# 2145    184520  281899  281900
# ...        ...     ...     ...
# 316104   45535   81584   81585
# 316373  288872  294219  122887
# 317754  248848  285169  362342
# 318279  102122  169021  169022
# 319355  273876  392410  392411
#
#                                                 question1  \
# 154            How do I overcome my inferiority complex ?
# 170                How can I make money as a 13 year old?
# 246            What are the most haunted places in delhi?
# 1723    What language is used in Visual Basic? How doe...
# 2145             What are the best things about modeling?
# ...                                                   ...
# 316104                    What is the definition of blog?
# 316373           What is the difference between : and ; ?
# 317754                        What does this symbol mean?
# 318279                               What is refrigerant?
# 319355                                    What is Timing?
#
#                                                 question2  is_duplicate
# 154             How do I overcome my inferiority complex?             0
# 170          How can I make money as a thirteen year old?             0
# 246             What are the most haunted place in delhi?             0
# 1723    What language is used in Visual Basic? How doe...             0
# 2145               What are the best things about models?             0
# ...                                                   ...           ...
# 316104                What is the definition of blogging?             0
# 316373    What is the difference between ":=" and "::=" ?             0
# 317754                    What does this '≜' symbol mean?             0
# 318279                             What is refrigeration?             0
# 319355                                     What is timee?             0
#
# [230 rows x 6 columns]
