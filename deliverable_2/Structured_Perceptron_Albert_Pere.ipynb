# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm, trange

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

pd.set_option('display.max_rows', 25)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 50)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Using ffill we optimize the code. It will fill all missing values with the previous non-nan value
data = pd.read_csv("data/kaggle_ner/ner_dataset.csv",
                   encoding="latin1").fillna(method="ffill")

data.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1  Sentence: 1             of   IN   O
# 2  Sentence: 1  demonstrators  NNS   O
# 3  Sentence: 1           have  VBP   O
# 4  Sentence: 1        marched  VBN   O

# %%
print("Available TAGS:")
print(set(data["Tag"]))
# Out:
# Available TAGS:
# {'I-geo', 'I-art', 'I-org', 'I-eve', 'I-tim', 'B-geo', 'B-org', 'O', 'B-art', 'B-tim', 'I-gpe', 'B-gpe', 'B-per', 'I-per', 'B-nat', 'B-eve', 'I-nat'}

# %%
print("{:10s} | {:20s}".format("TAG", "Examples"))
print("-"*60)
for tag in set(data["Tag"]):
    print("{:10s} | {:20s} {:20s} {:20s}".format(tag, *data[data["Tag"] == tag]["Word"][0:3].values))
# Out:
# TAG        | Examples
# ------------------------------------------------------------
# I-geo      | Park                 State                State
# I-art      | Non-Proliferation    V-6                  Simple
# I-org      | Party                Atomic               Energy
# I-eve      | Summer               Olympics             Olympic
# I-tim      | 8                    1                    2
# B-geo      | London               Iraq                 Hyde
# B-org      | Labor                International        IAEA
# O          | Thousands            of                   demonstrators
# B-art      | Nuclear              Saltillo             Pentastar
# B-tim      | Wednesday            Wednesday            Tuesday
# I-gpe      | States               Korea                Binh
# B-gpe      | British              English              Britain
# B-per      | Bush                 President            Thomas
# I-per      | Mahmoud              Ahmadinejad          Horbach
# B-nat      | H5N1                 H5N1                 Jing
# B-eve      | 2012                 Games                Games
# I-nat      | Jing                 Jing                 Acute

# %%
n_sentences = len(data['Sentence #'].unique())
n_sentences
# Out:
# 47959

# %%
# Using groupby and apply rather than a for loop the computation is reduced from +2h to 4s
# %time X_txt = list(data.groupby("Sentence #")['Word'].apply(list))
# %time Y_txt = list(data.groupby("Sentence #")['Tag'].apply(list))

from skseq.sequences.label_dictionary import LabelDictionary
x_dict = LabelDictionary(label_names=data['Word'].unique())
y_dict = LabelDictionary(label_names=data['Tag'].unique())
# Out:
# Wall time: 3.39 s
# Wall time: 3.28 s

# %%
import scipy
import numpy as np

import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

import skseq
import skseq.sequences
import skseq.readers
from skseq.sequences import sequence
from skseq.sequences import sequence_list
from skseq.sequences import label_dictionary

# %%
n_split = 35971
X_train_txt, X_test_txt, Y_train_txt, Y_test_txt = X_txt[:n_split], X_txt[n_split:], Y_txt[:n_split], Y_txt[n_split:]

# %%
from skseq.sequences.sequence_list import SequenceList
from skseq.sequences.sequence import Sequence

# train_sequences = [Sequence(x,y) for x,y in zip(X_train_txt, Y_train_txt)]
# test_sequences = [Sequence(x,y) for x,y in zip(X_test_txt, Y_test_txt)]

train_seq_list = SequenceList(x_dict, y_dict)
for x,y in zip(X_train_txt, Y_train_txt):
    train_seq_list.add_sequence(x, y, x_dict, y_dict)

test_seq_list = SequenceList(x_dict, y_dict)
for x,y in zip(X_test_txt, Y_test_txt):
    test_seq_list.add_sequence(x, y, x_dict, y_dict)

# %%
feature_mapper = skseq.sequences.id_feature.IDFeatures(train_seq_list)
feature_mapper.build_features()

print('Feature dict length:', len(feature_mapper.feature_dict))
print('Feature list length:', len(feature_mapper.feature_list))

import skseq.sequences.structured_perceptron as spc
# sp = spc.StructuredPerceptron(corpus.word_dict, corpus.tag_dict, feature_mapper)
sp = spc.StructuredPerceptron(x_dict, y_dict, feature_mapper)
# Out:
# Feature dict length: 38298
# Feature list length: 35971

# %%
def evaluate_corpus(sequences, sequences_predictions):
    """Evaluate classification accuracy at corpus level, comparing with
    gold standard."""
    total = 0.0
    correct = 0.0
    for i, sequence in enumerate(tqdm(sequences, leave=False)):
        pred = sequences_predictions[i]
        for j, y_hat in enumerate(pred.y):
            if sequence.y[j] == y_hat:
                correct += 1
            total += 1
    return correct / total

def train_perceptron(load_no_fit = True):
    if not load_no_fit:
        num_epochs = 50
        # %time sp.fit(train_seq_list, num_epochs)
        sp.save_model("")
    else:
        sp.load_model("")

# %%
import pandas as pd
from IPython.core import display as ICD

# %%
def evaluate_perceptron():
    # Make predictions for the various sequences using the trained model.
    pred_train = sp.viterbi_decode_corpus(train_seq_list)
    pred_test  = sp.viterbi_decode_corpus(test_seq_list)

    # Evaluate and print accuracies
    eval_train = evaluate_corpus(train_seq_list.seq_list, pred_train)
    eval_test = evaluate_corpus(test_seq_list.seq_list, pred_test)

    print("SP -  Accuracy Train: %.3f Test: %.3f"%(eval_train, eval_test))
    
def predict_text_tags(seq, nice_format=False):
    assert isinstance(seq, str) or isinstance(seq, list), "The input must be a sentence (string format or a list of words)"
    
    if isinstance(seq, str):
        seq = seq.split()
    
    num2lab = {v:k for k,v in sp.state_labels.items()}
    if nice_format:
        grp = pd.DataFrame([seq, [num2lab[w] for w in sp.predict_tags_given_words(seq)]], 
                           index=["Words", "Tags"], columns=["W_{:02d}".format(i) for i in range(len(seq))])   
        grp = grp.style.applymap(lambda x: 'color: blue' if x != 'O' and x in sp.state_labels else 'color: black')
        ICD.display(grp)
        
    else:
        res = ""
        for o, w in zip(seq, sp.predict_tags_given_words(seq)):
            ft = " {}/{}" if num2lab[w]=='O' else " {}/\x1b[34m{}\x1b[0m"
            res += ft.format(o, num2lab[w]) 
        print(res)
            
#         print(" ".join(["{}/{}".format(o, num2lab[w]) for o, w in zip(seq, sp.predict_tags_given_words(seq))]))
    
    
def predict_batch_text_tags(batch, nice_format=False):
    all_s = sum(isinstance(seq, str) for seq in batch)
    all_l = sum(isinstance(seq, list) for seq in batch)
    assert all_s==0 or all_l==0, "The inputs must be sentences (string format or lists of words)"

    for b in batch:
        predict_text_tags(b, nice_format)

# %%
train_perceptron(load_no_fit=True)
# evaluate_perceptron()

# %%
predict_text_tags("Jack London went to Paris".split())
predict_text_tags("Jack London went to Paris.".split())

# predict_text_tags("Jack London went to Paris".split(), nice_format=True)
# Out:
#  Jack/B-per London/I-per went/O to/O Paris/B-geo
#  Jack/B-per London/I-per went/O to/O Paris./O

# %%
sp.predict_tags_given_words(['Jack', 'London', 'went', 'to', 'Paris'])
# Out:
# array([ 3, 10,  0,  0,  1])

# %%
predict_batch_text_tags(["The programmers from Barcelona might write a sentence without a spell checker.",
"The programmers from Barchelona cannot write a sentence without a spell checker.",
"Jack London went to Parris.",
"Jack London went to Paris.",
"We never though Microsoft would become such a big company.",
"We never though Microsof would become such a big company.",
"The president of U.S.A though they could win the war",
"The president of the United States of America though they could win the war",
"The king of Saudi Arabia wanted total control.",
"Robin does not want to go to Saudi Arabia.",
"Apple is a great company.",
"I really love apples and oranges."])
# Out:
#  The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/B-per checker./I-per
#  The/O programmers/O from/O Barchelona/B-org cannot/I-org write/I-org a/O sentence/O without/O a/O spell/B-per checker./I-per
#  Jack/B-per London/I-per went/O to/O Parris./O
#  Jack/B-per London/I-per went/O to/O Paris./O
#  We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
#  We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
#  The/O president/O of/O U.S.A/B-org though/O they/O could/O win/O the/O war/O
#  The/O president/O of/O the/O United/B-geo States/I-geo of/I-geo America/I-geo though/O they/O could/O win/O the/O war/O
#  The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
#  Robin/O does/O not/O want/O to/O go/O to/O Saudi/B-per Arabia./I-per
#  Apple/B-org is/O a/O great/O company./O
#  I/O really/O love/O apples/O and/O oranges./O

# %%
predict_batch_text_tags(["The programmers from Barcelona might write a sentence without a spell checker.",
"The programmers from Barchelona cannot write a sentence without a spell checker.",
"Jack London went to Parris.",
"Jack London went to Paris.",
"We never though Microsoft would become such a big company.",
"We never though Microsof would become such a big company.",
"The president of U.S.A though they could win the war",
"The president of the United States of America though they could win the war",
"The king of Saudi Arabia wanted total control.",
"Robin does not want to go to Saudi Arabia.",
"Apple is a great company.",
"I really love apples and oranges."], nice_format=True)
# Out:
# <style  type="text/css" >
#     #T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col0 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col1 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col2 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col3 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col4 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col5 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col6 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col7 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col8 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col9 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col10 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col11 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col0 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col1 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col2 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col3 {
#             color:  blue;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col4 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col5 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col6 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col7 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col8 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col9 {
#             color:  black;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col10 {
#             color:  blue;
#         }    #T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col11 {
#             color:  blue;
#         }</style><table id="T_12b907d2_b159_11ea_9bb6_00e04c681714" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >W_00</th>        <th class="col_heading level0 col1" >W_01</th>        <th class="col_heading level0 col2" >W_02</th>        <th class="col_heading level0 col3" >W_03</th>        <th class="col_heading level0 col4" >W_04</th>        <th class="col_heading level0 col5" >W_05</th>        <th class="col_heading level0 col6" >W_06</th>        <th class="col_heading level0 col7" >W_07</th>        <th class="col_heading level0 col8" >W_08</th>        <th class="col_heading level0 col9" >W_09</th>        <th class="col_heading level0 col10" >W_10</th>        <th class="col_heading level0 col11" >W_11</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12b907d2_b159_11ea_9bb6_00e04c681714level0_row0" class="row_heading level0 row0" >Words</th>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col0" class="data row0 col0" >The</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col1" class="data row0 col1" >programmers</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col2" class="data row0 col2" >from</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col3" class="data row0 col3" >Barcelona</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col4" class="data row0 col4" >might</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col5" class="data row0 col5" >write</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col6" class="data row0 col6" >a</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col7" class="data row0 col7" >sentence</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col8" class="data row0 col8" >without</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col9" class="data row0 col9" >a</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col10" class="data row0 col10" >spell</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row0_col11" class="data row0 col11" >checker.</td>
#             </tr>
#             <tr>
#                         <th id="T_12b907d2_b159_11ea_9bb6_00e04c681714level0_row1" class="row_heading level0 row1" >Tags</th>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col0" class="data row1 col0" >O</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col1" class="data row1 col1" >O</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col2" class="data row1 col2" >O</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col3" class="data row1 col3" >B-geo</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col4" class="data row1 col4" >O</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col5" class="data row1 col5" >O</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col6" class="data row1 col6" >O</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col7" class="data row1 col7" >O</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col8" class="data row1 col8" >O</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col9" class="data row1 col9" >O</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col10" class="data row1 col10" >B-per</td>
#                         <td id="T_12b907d2_b159_11ea_9bb6_00e04c681714row1_col11" class="data row1 col11" >I-per</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col0 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col1 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col2 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col3 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col4 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col5 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col6 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col7 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col8 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col9 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col10 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col11 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col0 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col1 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col2 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col3 {
#             color:  blue;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col4 {
#             color:  blue;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col5 {
#             color:  blue;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col6 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col7 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col8 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col9 {
#             color:  black;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col10 {
#             color:  blue;
#         }    #T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col11 {
#             color:  blue;
#         }</style><table id="T_12ba8fb6_b159_11ea_bab2_00e04c681714" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >W_00</th>        <th class="col_heading level0 col1" >W_01</th>        <th class="col_heading level0 col2" >W_02</th>        <th class="col_heading level0 col3" >W_03</th>        <th class="col_heading level0 col4" >W_04</th>        <th class="col_heading level0 col5" >W_05</th>        <th class="col_heading level0 col6" >W_06</th>        <th class="col_heading level0 col7" >W_07</th>        <th class="col_heading level0 col8" >W_08</th>        <th class="col_heading level0 col9" >W_09</th>        <th class="col_heading level0 col10" >W_10</th>        <th class="col_heading level0 col11" >W_11</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12ba8fb6_b159_11ea_bab2_00e04c681714level0_row0" class="row_heading level0 row0" >Words</th>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col0" class="data row0 col0" >The</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col1" class="data row0 col1" >programmers</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col2" class="data row0 col2" >from</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col3" class="data row0 col3" >Barchelona</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col4" class="data row0 col4" >cannot</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col5" class="data row0 col5" >write</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col6" class="data row0 col6" >a</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col7" class="data row0 col7" >sentence</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col8" class="data row0 col8" >without</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col9" class="data row0 col9" >a</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col10" class="data row0 col10" >spell</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row0_col11" class="data row0 col11" >checker.</td>
#             </tr>
#             <tr>
#                         <th id="T_12ba8fb6_b159_11ea_bab2_00e04c681714level0_row1" class="row_heading level0 row1" >Tags</th>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col0" class="data row1 col0" >O</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col1" class="data row1 col1" >O</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col2" class="data row1 col2" >O</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col3" class="data row1 col3" >B-org</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col4" class="data row1 col4" >I-org</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col5" class="data row1 col5" >I-org</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col6" class="data row1 col6" >O</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col7" class="data row1 col7" >O</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col8" class="data row1 col8" >O</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col9" class="data row1 col9" >O</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col10" class="data row1 col10" >B-per</td>
#                         <td id="T_12ba8fb6_b159_11ea_bab2_00e04c681714row1_col11" class="data row1 col11" >I-per</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_12bc21da_b159_11ea_a7f0_00e04c681714row0_col0 {
#             color:  black;
#         }    #T_12bc21da_b159_11ea_a7f0_00e04c681714row0_col1 {
#             color:  black;
#         }    #T_12bc21da_b159_11ea_a7f0_00e04c681714row0_col2 {
#             color:  black;
#         }    #T_12bc21da_b159_11ea_a7f0_00e04c681714row0_col3 {
#             color:  black;
#         }    #T_12bc21da_b159_11ea_a7f0_00e04c681714row0_col4 {
#             color:  black;
#         }    #T_12bc21da_b159_11ea_a7f0_00e04c681714row1_col0 {
#             color:  blue;
#         }    #T_12bc21da_b159_11ea_a7f0_00e04c681714row1_col1 {
#             color:  blue;
#         }    #T_12bc21da_b159_11ea_a7f0_00e04c681714row1_col2 {
#             color:  black;
#         }    #T_12bc21da_b159_11ea_a7f0_00e04c681714row1_col3 {
#             color:  black;
#         }    #T_12bc21da_b159_11ea_a7f0_00e04c681714row1_col4 {
#             color:  black;
#         }</style><table id="T_12bc21da_b159_11ea_a7f0_00e04c681714" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >W_00</th>        <th class="col_heading level0 col1" >W_01</th>        <th class="col_heading level0 col2" >W_02</th>        <th class="col_heading level0 col3" >W_03</th>        <th class="col_heading level0 col4" >W_04</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12bc21da_b159_11ea_a7f0_00e04c681714level0_row0" class="row_heading level0 row0" >Words</th>
#                         <td id="T_12bc21da_b159_11ea_a7f0_00e04c681714row0_col0" class="data row0 col0" >Jack</td>
#                         <td id="T_12bc21da_b159_11ea_a7f0_00e04c681714row0_col1" class="data row0 col1" >London</td>
#                         <td id="T_12bc21da_b159_11ea_a7f0_00e04c681714row0_col2" class="data row0 col2" >went</td>
#                         <td id="T_12bc21da_b159_11ea_a7f0_00e04c681714row0_col3" class="data row0 col3" >to</td>
#                         <td id="T_12bc21da_b159_11ea_a7f0_00e04c681714row0_col4" class="data row0 col4" >Parris.</td>
#             </tr>
#             <tr>
#                         <th id="T_12bc21da_b159_11ea_a7f0_00e04c681714level0_row1" class="row_heading level0 row1" >Tags</th>
#                         <td id="T_12bc21da_b159_11ea_a7f0_00e04c681714row1_col0" class="data row1 col0" >B-per</td>
#                         <td id="T_12bc21da_b159_11ea_a7f0_00e04c681714row1_col1" class="data row1 col1" >I-per</td>
#                         <td id="T_12bc21da_b159_11ea_a7f0_00e04c681714row1_col2" class="data row1 col2" >O</td>
#                         <td id="T_12bc21da_b159_11ea_a7f0_00e04c681714row1_col3" class="data row1 col3" >O</td>
#                         <td id="T_12bc21da_b159_11ea_a7f0_00e04c681714row1_col4" class="data row1 col4" >O</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_12bd9ba4_b159_11ea_b3c3_00e04c681714row0_col0 {
#             color:  black;
#         }    #T_12bd9ba4_b159_11ea_b3c3_00e04c681714row0_col1 {
#             color:  black;
#         }    #T_12bd9ba4_b159_11ea_b3c3_00e04c681714row0_col2 {
#             color:  black;
#         }    #T_12bd9ba4_b159_11ea_b3c3_00e04c681714row0_col3 {
#             color:  black;
#         }    #T_12bd9ba4_b159_11ea_b3c3_00e04c681714row0_col4 {
#             color:  black;
#         }    #T_12bd9ba4_b159_11ea_b3c3_00e04c681714row1_col0 {
#             color:  blue;
#         }    #T_12bd9ba4_b159_11ea_b3c3_00e04c681714row1_col1 {
#             color:  blue;
#         }    #T_12bd9ba4_b159_11ea_b3c3_00e04c681714row1_col2 {
#             color:  black;
#         }    #T_12bd9ba4_b159_11ea_b3c3_00e04c681714row1_col3 {
#             color:  black;
#         }    #T_12bd9ba4_b159_11ea_b3c3_00e04c681714row1_col4 {
#             color:  black;
#         }</style><table id="T_12bd9ba4_b159_11ea_b3c3_00e04c681714" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >W_00</th>        <th class="col_heading level0 col1" >W_01</th>        <th class="col_heading level0 col2" >W_02</th>        <th class="col_heading level0 col3" >W_03</th>        <th class="col_heading level0 col4" >W_04</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12bd9ba4_b159_11ea_b3c3_00e04c681714level0_row0" class="row_heading level0 row0" >Words</th>
#                         <td id="T_12bd9ba4_b159_11ea_b3c3_00e04c681714row0_col0" class="data row0 col0" >Jack</td>
#                         <td id="T_12bd9ba4_b159_11ea_b3c3_00e04c681714row0_col1" class="data row0 col1" >London</td>
#                         <td id="T_12bd9ba4_b159_11ea_b3c3_00e04c681714row0_col2" class="data row0 col2" >went</td>
#                         <td id="T_12bd9ba4_b159_11ea_b3c3_00e04c681714row0_col3" class="data row0 col3" >to</td>
#                         <td id="T_12bd9ba4_b159_11ea_b3c3_00e04c681714row0_col4" class="data row0 col4" >Paris.</td>
#             </tr>
#             <tr>
#                         <th id="T_12bd9ba4_b159_11ea_b3c3_00e04c681714level0_row1" class="row_heading level0 row1" >Tags</th>
#                         <td id="T_12bd9ba4_b159_11ea_b3c3_00e04c681714row1_col0" class="data row1 col0" >B-per</td>
#                         <td id="T_12bd9ba4_b159_11ea_b3c3_00e04c681714row1_col1" class="data row1 col1" >I-per</td>
#                         <td id="T_12bd9ba4_b159_11ea_b3c3_00e04c681714row1_col2" class="data row1 col2" >O</td>
#                         <td id="T_12bd9ba4_b159_11ea_b3c3_00e04c681714row1_col3" class="data row1 col3" >O</td>
#                         <td id="T_12bd9ba4_b159_11ea_b3c3_00e04c681714row1_col4" class="data row1 col4" >O</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col0 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col1 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col2 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col3 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col4 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col5 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col6 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col7 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col8 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col9 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col0 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col1 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col2 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col3 {
#             color:  blue;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col4 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col5 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col6 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col7 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col8 {
#             color:  black;
#         }    #T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col9 {
#             color:  black;
#         }</style><table id="T_12bf32cc_b159_11ea_85ea_00e04c681714" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >W_00</th>        <th class="col_heading level0 col1" >W_01</th>        <th class="col_heading level0 col2" >W_02</th>        <th class="col_heading level0 col3" >W_03</th>        <th class="col_heading level0 col4" >W_04</th>        <th class="col_heading level0 col5" >W_05</th>        <th class="col_heading level0 col6" >W_06</th>        <th class="col_heading level0 col7" >W_07</th>        <th class="col_heading level0 col8" >W_08</th>        <th class="col_heading level0 col9" >W_09</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12bf32cc_b159_11ea_85ea_00e04c681714level0_row0" class="row_heading level0 row0" >Words</th>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col0" class="data row0 col0" >We</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col1" class="data row0 col1" >never</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col2" class="data row0 col2" >though</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col3" class="data row0 col3" >Microsoft</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col4" class="data row0 col4" >would</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col5" class="data row0 col5" >become</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col6" class="data row0 col6" >such</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col7" class="data row0 col7" >a</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col8" class="data row0 col8" >big</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row0_col9" class="data row0 col9" >company.</td>
#             </tr>
#             <tr>
#                         <th id="T_12bf32cc_b159_11ea_85ea_00e04c681714level0_row1" class="row_heading level0 row1" >Tags</th>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col0" class="data row1 col0" >O</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col1" class="data row1 col1" >O</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col2" class="data row1 col2" >O</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col3" class="data row1 col3" >B-org</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col4" class="data row1 col4" >O</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col5" class="data row1 col5" >O</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col6" class="data row1 col6" >O</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col7" class="data row1 col7" >O</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col8" class="data row1 col8" >O</td>
#                         <td id="T_12bf32cc_b159_11ea_85ea_00e04c681714row1_col9" class="data row1 col9" >O</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_12c23090_b159_11ea_98cb_00e04c681714row0_col0 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row0_col1 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row0_col2 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row0_col3 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row0_col4 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row0_col5 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row0_col6 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row0_col7 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row0_col8 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row0_col9 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row1_col0 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row1_col1 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row1_col2 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row1_col3 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row1_col4 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row1_col5 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row1_col6 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row1_col7 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row1_col8 {
#             color:  black;
#         }    #T_12c23090_b159_11ea_98cb_00e04c681714row1_col9 {
#             color:  black;
#         }</style><table id="T_12c23090_b159_11ea_98cb_00e04c681714" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >W_00</th>        <th class="col_heading level0 col1" >W_01</th>        <th class="col_heading level0 col2" >W_02</th>        <th class="col_heading level0 col3" >W_03</th>        <th class="col_heading level0 col4" >W_04</th>        <th class="col_heading level0 col5" >W_05</th>        <th class="col_heading level0 col6" >W_06</th>        <th class="col_heading level0 col7" >W_07</th>        <th class="col_heading level0 col8" >W_08</th>        <th class="col_heading level0 col9" >W_09</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12c23090_b159_11ea_98cb_00e04c681714level0_row0" class="row_heading level0 row0" >Words</th>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row0_col0" class="data row0 col0" >We</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row0_col1" class="data row0 col1" >never</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row0_col2" class="data row0 col2" >though</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row0_col3" class="data row0 col3" >Microsof</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row0_col4" class="data row0 col4" >would</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row0_col5" class="data row0 col5" >become</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row0_col6" class="data row0 col6" >such</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row0_col7" class="data row0 col7" >a</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row0_col8" class="data row0 col8" >big</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row0_col9" class="data row0 col9" >company.</td>
#             </tr>
#             <tr>
#                         <th id="T_12c23090_b159_11ea_98cb_00e04c681714level0_row1" class="row_heading level0 row1" >Tags</th>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row1_col0" class="data row1 col0" >O</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row1_col1" class="data row1 col1" >O</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row1_col2" class="data row1 col2" >O</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row1_col3" class="data row1 col3" >O</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row1_col4" class="data row1 col4" >O</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row1_col5" class="data row1 col5" >O</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row1_col6" class="data row1 col6" >O</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row1_col7" class="data row1 col7" >O</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row1_col8" class="data row1 col8" >O</td>
#                         <td id="T_12c23090_b159_11ea_98cb_00e04c681714row1_col9" class="data row1 col9" >O</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_12c3b906_b159_11ea_be1c_00e04c681714row0_col0 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row0_col1 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row0_col2 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row0_col3 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row0_col4 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row0_col5 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row0_col6 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row0_col7 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row0_col8 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row0_col9 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row1_col0 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row1_col1 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row1_col2 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row1_col3 {
#             color:  blue;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row1_col4 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row1_col5 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row1_col6 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row1_col7 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row1_col8 {
#             color:  black;
#         }    #T_12c3b906_b159_11ea_be1c_00e04c681714row1_col9 {
#             color:  black;
#         }</style><table id="T_12c3b906_b159_11ea_be1c_00e04c681714" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >W_00</th>        <th class="col_heading level0 col1" >W_01</th>        <th class="col_heading level0 col2" >W_02</th>        <th class="col_heading level0 col3" >W_03</th>        <th class="col_heading level0 col4" >W_04</th>        <th class="col_heading level0 col5" >W_05</th>        <th class="col_heading level0 col6" >W_06</th>        <th class="col_heading level0 col7" >W_07</th>        <th class="col_heading level0 col8" >W_08</th>        <th class="col_heading level0 col9" >W_09</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12c3b906_b159_11ea_be1c_00e04c681714level0_row0" class="row_heading level0 row0" >Words</th>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row0_col0" class="data row0 col0" >The</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row0_col1" class="data row0 col1" >president</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row0_col2" class="data row0 col2" >of</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row0_col3" class="data row0 col3" >U.S.A</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row0_col4" class="data row0 col4" >though</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row0_col5" class="data row0 col5" >they</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row0_col6" class="data row0 col6" >could</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row0_col7" class="data row0 col7" >win</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row0_col8" class="data row0 col8" >the</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row0_col9" class="data row0 col9" >war</td>
#             </tr>
#             <tr>
#                         <th id="T_12c3b906_b159_11ea_be1c_00e04c681714level0_row1" class="row_heading level0 row1" >Tags</th>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row1_col0" class="data row1 col0" >O</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row1_col1" class="data row1 col1" >O</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row1_col2" class="data row1 col2" >O</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row1_col3" class="data row1 col3" >B-org</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row1_col4" class="data row1 col4" >O</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row1_col5" class="data row1 col5" >O</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row1_col6" class="data row1 col6" >O</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row1_col7" class="data row1 col7" >O</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row1_col8" class="data row1 col8" >O</td>
#                         <td id="T_12c3b906_b159_11ea_be1c_00e04c681714row1_col9" class="data row1 col9" >O</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col0 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col1 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col2 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col3 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col4 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col5 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col6 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col7 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col8 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col9 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col10 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col11 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col12 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col13 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col0 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col1 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col2 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col3 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col4 {
#             color:  blue;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col5 {
#             color:  blue;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col6 {
#             color:  blue;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col7 {
#             color:  blue;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col8 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col9 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col10 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col11 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col12 {
#             color:  black;
#         }    #T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col13 {
#             color:  black;
#         }</style><table id="T_12c6c1ee_b159_11ea_ab20_00e04c681714" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >W_00</th>        <th class="col_heading level0 col1" >W_01</th>        <th class="col_heading level0 col2" >W_02</th>        <th class="col_heading level0 col3" >W_03</th>        <th class="col_heading level0 col4" >W_04</th>        <th class="col_heading level0 col5" >W_05</th>        <th class="col_heading level0 col6" >W_06</th>        <th class="col_heading level0 col7" >W_07</th>        <th class="col_heading level0 col8" >W_08</th>        <th class="col_heading level0 col9" >W_09</th>        <th class="col_heading level0 col10" >W_10</th>        <th class="col_heading level0 col11" >W_11</th>        <th class="col_heading level0 col12" >W_12</th>        <th class="col_heading level0 col13" >W_13</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12c6c1ee_b159_11ea_ab20_00e04c681714level0_row0" class="row_heading level0 row0" >Words</th>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col0" class="data row0 col0" >The</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col1" class="data row0 col1" >president</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col2" class="data row0 col2" >of</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col3" class="data row0 col3" >the</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col4" class="data row0 col4" >United</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col5" class="data row0 col5" >States</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col6" class="data row0 col6" >of</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col7" class="data row0 col7" >America</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col8" class="data row0 col8" >though</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col9" class="data row0 col9" >they</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col10" class="data row0 col10" >could</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col11" class="data row0 col11" >win</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col12" class="data row0 col12" >the</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row0_col13" class="data row0 col13" >war</td>
#             </tr>
#             <tr>
#                         <th id="T_12c6c1ee_b159_11ea_ab20_00e04c681714level0_row1" class="row_heading level0 row1" >Tags</th>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col0" class="data row1 col0" >O</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col1" class="data row1 col1" >O</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col2" class="data row1 col2" >O</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col3" class="data row1 col3" >O</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col4" class="data row1 col4" >B-geo</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col5" class="data row1 col5" >I-geo</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col6" class="data row1 col6" >I-geo</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col7" class="data row1 col7" >I-geo</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col8" class="data row1 col8" >O</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col9" class="data row1 col9" >O</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col10" class="data row1 col10" >O</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col11" class="data row1 col11" >O</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col12" class="data row1 col12" >O</td>
#                         <td id="T_12c6c1ee_b159_11ea_ab20_00e04c681714row1_col13" class="data row1 col13" >O</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col0 {
#             color:  black;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col1 {
#             color:  black;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col2 {
#             color:  black;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col3 {
#             color:  black;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col4 {
#             color:  black;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col5 {
#             color:  black;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col6 {
#             color:  black;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col7 {
#             color:  black;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col0 {
#             color:  black;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col1 {
#             color:  black;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col2 {
#             color:  black;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col3 {
#             color:  blue;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col4 {
#             color:  blue;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col5 {
#             color:  black;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col6 {
#             color:  black;
#         }    #T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col7 {
#             color:  black;
#         }</style><table id="T_12c8598c_b159_11ea_b4a4_00e04c681714" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >W_00</th>        <th class="col_heading level0 col1" >W_01</th>        <th class="col_heading level0 col2" >W_02</th>        <th class="col_heading level0 col3" >W_03</th>        <th class="col_heading level0 col4" >W_04</th>        <th class="col_heading level0 col5" >W_05</th>        <th class="col_heading level0 col6" >W_06</th>        <th class="col_heading level0 col7" >W_07</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12c8598c_b159_11ea_b4a4_00e04c681714level0_row0" class="row_heading level0 row0" >Words</th>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col0" class="data row0 col0" >The</td>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col1" class="data row0 col1" >king</td>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col2" class="data row0 col2" >of</td>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col3" class="data row0 col3" >Saudi</td>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col4" class="data row0 col4" >Arabia</td>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col5" class="data row0 col5" >wanted</td>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col6" class="data row0 col6" >total</td>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row0_col7" class="data row0 col7" >control.</td>
#             </tr>
#             <tr>
#                         <th id="T_12c8598c_b159_11ea_b4a4_00e04c681714level0_row1" class="row_heading level0 row1" >Tags</th>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col0" class="data row1 col0" >O</td>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col1" class="data row1 col1" >O</td>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col2" class="data row1 col2" >O</td>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col3" class="data row1 col3" >B-geo</td>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col4" class="data row1 col4" >I-geo</td>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col5" class="data row1 col5" >O</td>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col6" class="data row1 col6" >O</td>
#                         <td id="T_12c8598c_b159_11ea_b4a4_00e04c681714row1_col7" class="data row1 col7" >O</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col0 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col1 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col2 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col3 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col4 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col5 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col6 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col7 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col8 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col0 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col1 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col2 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col3 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col4 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col5 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col6 {
#             color:  black;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col7 {
#             color:  blue;
#         }    #T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col8 {
#             color:  blue;
#         }</style><table id="T_12cb5ba2_b159_11ea_bd44_00e04c681714" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >W_00</th>        <th class="col_heading level0 col1" >W_01</th>        <th class="col_heading level0 col2" >W_02</th>        <th class="col_heading level0 col3" >W_03</th>        <th class="col_heading level0 col4" >W_04</th>        <th class="col_heading level0 col5" >W_05</th>        <th class="col_heading level0 col6" >W_06</th>        <th class="col_heading level0 col7" >W_07</th>        <th class="col_heading level0 col8" >W_08</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12cb5ba2_b159_11ea_bd44_00e04c681714level0_row0" class="row_heading level0 row0" >Words</th>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col0" class="data row0 col0" >Robin</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col1" class="data row0 col1" >does</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col2" class="data row0 col2" >not</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col3" class="data row0 col3" >want</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col4" class="data row0 col4" >to</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col5" class="data row0 col5" >go</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col6" class="data row0 col6" >to</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col7" class="data row0 col7" >Saudi</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row0_col8" class="data row0 col8" >Arabia.</td>
#             </tr>
#             <tr>
#                         <th id="T_12cb5ba2_b159_11ea_bd44_00e04c681714level0_row1" class="row_heading level0 row1" >Tags</th>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col0" class="data row1 col0" >O</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col1" class="data row1 col1" >O</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col2" class="data row1 col2" >O</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col3" class="data row1 col3" >O</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col4" class="data row1 col4" >O</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col5" class="data row1 col5" >O</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col6" class="data row1 col6" >O</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col7" class="data row1 col7" >B-per</td>
#                         <td id="T_12cb5ba2_b159_11ea_bd44_00e04c681714row1_col8" class="data row1 col8" >I-per</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_12cce3a2_b159_11ea_a56f_00e04c681714row0_col0 {
#             color:  black;
#         }    #T_12cce3a2_b159_11ea_a56f_00e04c681714row0_col1 {
#             color:  black;
#         }    #T_12cce3a2_b159_11ea_a56f_00e04c681714row0_col2 {
#             color:  black;
#         }    #T_12cce3a2_b159_11ea_a56f_00e04c681714row0_col3 {
#             color:  black;
#         }    #T_12cce3a2_b159_11ea_a56f_00e04c681714row0_col4 {
#             color:  black;
#         }    #T_12cce3a2_b159_11ea_a56f_00e04c681714row1_col0 {
#             color:  blue;
#         }    #T_12cce3a2_b159_11ea_a56f_00e04c681714row1_col1 {
#             color:  black;
#         }    #T_12cce3a2_b159_11ea_a56f_00e04c681714row1_col2 {
#             color:  black;
#         }    #T_12cce3a2_b159_11ea_a56f_00e04c681714row1_col3 {
#             color:  black;
#         }    #T_12cce3a2_b159_11ea_a56f_00e04c681714row1_col4 {
#             color:  black;
#         }</style><table id="T_12cce3a2_b159_11ea_a56f_00e04c681714" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >W_00</th>        <th class="col_heading level0 col1" >W_01</th>        <th class="col_heading level0 col2" >W_02</th>        <th class="col_heading level0 col3" >W_03</th>        <th class="col_heading level0 col4" >W_04</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12cce3a2_b159_11ea_a56f_00e04c681714level0_row0" class="row_heading level0 row0" >Words</th>
#                         <td id="T_12cce3a2_b159_11ea_a56f_00e04c681714row0_col0" class="data row0 col0" >Apple</td>
#                         <td id="T_12cce3a2_b159_11ea_a56f_00e04c681714row0_col1" class="data row0 col1" >is</td>
#                         <td id="T_12cce3a2_b159_11ea_a56f_00e04c681714row0_col2" class="data row0 col2" >a</td>
#                         <td id="T_12cce3a2_b159_11ea_a56f_00e04c681714row0_col3" class="data row0 col3" >great</td>
#                         <td id="T_12cce3a2_b159_11ea_a56f_00e04c681714row0_col4" class="data row0 col4" >company.</td>
#             </tr>
#             <tr>
#                         <th id="T_12cce3a2_b159_11ea_a56f_00e04c681714level0_row1" class="row_heading level0 row1" >Tags</th>
#                         <td id="T_12cce3a2_b159_11ea_a56f_00e04c681714row1_col0" class="data row1 col0" >B-org</td>
#                         <td id="T_12cce3a2_b159_11ea_a56f_00e04c681714row1_col1" class="data row1 col1" >O</td>
#                         <td id="T_12cce3a2_b159_11ea_a56f_00e04c681714row1_col2" class="data row1 col2" >O</td>
#                         <td id="T_12cce3a2_b159_11ea_a56f_00e04c681714row1_col3" class="data row1 col3" >O</td>
#                         <td id="T_12cce3a2_b159_11ea_a56f_00e04c681714row1_col4" class="data row1 col4" >O</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_12cda726_b159_11ea_bd52_00e04c681714row0_col0 {
#             color:  black;
#         }    #T_12cda726_b159_11ea_bd52_00e04c681714row0_col1 {
#             color:  black;
#         }    #T_12cda726_b159_11ea_bd52_00e04c681714row0_col2 {
#             color:  black;
#         }    #T_12cda726_b159_11ea_bd52_00e04c681714row0_col3 {
#             color:  black;
#         }    #T_12cda726_b159_11ea_bd52_00e04c681714row0_col4 {
#             color:  black;
#         }    #T_12cda726_b159_11ea_bd52_00e04c681714row0_col5 {
#             color:  black;
#         }    #T_12cda726_b159_11ea_bd52_00e04c681714row1_col0 {
#             color:  black;
#         }    #T_12cda726_b159_11ea_bd52_00e04c681714row1_col1 {
#             color:  black;
#         }    #T_12cda726_b159_11ea_bd52_00e04c681714row1_col2 {
#             color:  black;
#         }    #T_12cda726_b159_11ea_bd52_00e04c681714row1_col3 {
#             color:  black;
#         }    #T_12cda726_b159_11ea_bd52_00e04c681714row1_col4 {
#             color:  black;
#         }    #T_12cda726_b159_11ea_bd52_00e04c681714row1_col5 {
#             color:  black;
#         }</style><table id="T_12cda726_b159_11ea_bd52_00e04c681714" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >W_00</th>        <th class="col_heading level0 col1" >W_01</th>        <th class="col_heading level0 col2" >W_02</th>        <th class="col_heading level0 col3" >W_03</th>        <th class="col_heading level0 col4" >W_04</th>        <th class="col_heading level0 col5" >W_05</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12cda726_b159_11ea_bd52_00e04c681714level0_row0" class="row_heading level0 row0" >Words</th>
#                         <td id="T_12cda726_b159_11ea_bd52_00e04c681714row0_col0" class="data row0 col0" >I</td>
#                         <td id="T_12cda726_b159_11ea_bd52_00e04c681714row0_col1" class="data row0 col1" >really</td>
#                         <td id="T_12cda726_b159_11ea_bd52_00e04c681714row0_col2" class="data row0 col2" >love</td>
#                         <td id="T_12cda726_b159_11ea_bd52_00e04c681714row0_col3" class="data row0 col3" >apples</td>
#                         <td id="T_12cda726_b159_11ea_bd52_00e04c681714row0_col4" class="data row0 col4" >and</td>
#                         <td id="T_12cda726_b159_11ea_bd52_00e04c681714row0_col5" class="data row0 col5" >oranges.</td>
#             </tr>
#             <tr>
#                         <th id="T_12cda726_b159_11ea_bd52_00e04c681714level0_row1" class="row_heading level0 row1" >Tags</th>
#                         <td id="T_12cda726_b159_11ea_bd52_00e04c681714row1_col0" class="data row1 col0" >O</td>
#                         <td id="T_12cda726_b159_11ea_bd52_00e04c681714row1_col1" class="data row1 col1" >O</td>
#                         <td id="T_12cda726_b159_11ea_bd52_00e04c681714row1_col2" class="data row1 col2" >O</td>
#                         <td id="T_12cda726_b159_11ea_bd52_00e04c681714row1_col3" class="data row1 col3" >O</td>
#                         <td id="T_12cda726_b159_11ea_bd52_00e04c681714row1_col4" class="data row1 col4" >O</td>
#                         <td id="T_12cda726_b159_11ea_bd52_00e04c681714row1_col5" class="data row1 col5" >O</td>
#             </tr>
#     </tbody></table>
