# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')

from nltk.corpus import stopwords

import pandas as pd
import scipy
from sklearn import *
import re
from SimpleCountVectorizer import *
from TFIDFVectorizer import *

from nltk.stem import WordNetLemmatizer, SnowballStemmer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
"""Given an int32 number, print it in English."""
def int_to_en(num):
    d = { 0 : 'zero', 1 : 'one', 2 : 'two', 3 : 'three', 4 : 'four', 5 : 'five',
          6 : 'six', 7 : 'seven', 8 : 'eight', 9 : 'nine', 10 : 'ten',
          11 : 'eleven', 12 : 'twelve', 13 : 'thirteen', 14 : 'fourteen',
          15 : 'fifteen', 16 : 'sixteen', 17 : 'seventeen', 18 : 'eighteen',
          19 : 'nineteen', 20 : 'twenty',
          30 : 'thirty', 40 : 'forty', 50 : 'fifty', 60 : 'sixty',
          70 : 'seventy', 80 : 'eighty', 90 : 'ninety' }
    k = 1000
    m = k * 1000
    b = m * 1000
    t = b * 1000

    assert(0 <= num)

    if (num < 20):
        return d[num]

    if (num < 100):
        if num % 10 == 0: return d[num]
        else: return d[num // 10 * 10] + '-' + d[num % 10]

    if (num < k):
        if num % 100 == 0: return d[num // 100] + ' hundred'
        else: return d[num // 100] + ' hundred and ' + int_to_en(num % 100)

    if (num < m):
        if num % k == 0: return int_to_en(num // k) + ' thousand'
        else: return int_to_en(num // k) + ' thousand, ' + int_to_en(num % k)

    if (num < b):
        if (num % m) == 0: return int_to_en(num // m) + ' million'
        else: return int_to_en(num // m) + ' million, ' + int_to_en(num % m)

    if (num < t):
        if (num % b) == 0: return int_to_en(num // b) + ' billion'
        else: return int_to_en(num // b) + ' billion, ' + int_to_en(num % b)

    if (num % t == 0): return int_to_en(num // t) + ' trillion'
    else: return int_to_en(num // t) + ' trillion, ' + int_to_en(num % t)

    raise AssertionError('num is too large: %s' % str(num))

# %% [markdown]
# # Count Vectorizer

# %%
train_df = pd.read_csv("./data/quora_train_data.csv")
test_df = pd.read_csv('./data/quora_test_data.csv')

# train_df, test_df = sklearn.model_selection.train_test_split(train_df, test_size=0.1, random_state=123)

# %%
train_df.shape, test_df.shape
# Out:
# ((323432, 6), (80858, 6))

# %%
def cast_list_as_strings(mylist):
    """
    return a list of strings
    """
    assert isinstance(mylist, list), f"the input mylist should be a list it is {type(mylist)}"
    
    # return list(map(lambda x: str(x), all_questions)) # Slower
    return [str(s) for s in mylist]

# %%
all_questions = cast_list_as_strings(list(train_df.loc[:, 'question1'])+list(train_df.loc[:, 'question2']))
print(set(type(x).__name__ for x in all_questions))
# Out:
# {'str'}

# %%
def num_conv(s):
    try:
        return int_to_en(int(s)).replace(",","").replace(" ","_")
    except:
        return s


def my_doc_cleaner(doc,
                  pat=r"[^a-zA-Z0-9]"):
    # Allow alphanumeric characters
    doc_cleaner_pattern=pat
    clean_doc_pattern = re.compile(doc_cleaner_pattern)
    doc_clean = clean_doc_pattern.sub(" ", doc)
    return doc.lower()


# stpw = set(stopwords.words("english"))
stpw = []

stemmer =  SnowballStemmer(language='english')
lemmatizer = WordNetLemmatizer()

def my_tokenizer_func(doc, 
                      ngrams=(1,3), 
                      numbers_to_words=True,
                      stop_words=stpw,
                      pat=r"(?u)\b\w\S*\w*\b",
                      lem=True,
                      stem=True):
    
    # Split using a patterm
#     pat=r"(?u)\b\w\w+\b"
#     pat=r"(?u)\b\w\S*\w*\b"
    token_pattern = re.compile(pat)
    lst = token_pattern.findall(doc)
    
    # Transform numbers into words
    if numbers_to_words:
        lst = list(map(lambda x: num_conv(x), lst))
        
    # Drop stopwords 
    lst = list(filter(lambda x : x not in stop_words, lst))
    
    #Stemmer
    if stem:
        lst = list(map(lambda x: stemmer.stem(x), lst))
    
    #Lemmatizer 
    if lem:
        lst = list(map(lambda x: lemmatizer.lemmatize(x), lst))
        
    if ngrams==(1,1):
        return lst
    
    # Generate ngrams
    lstRet = []
    for a in range(ngrams[0], ngrams[1]+1):
        if a!=1:
            lstRet+=list(zip(*[lst[i:] for i in range(a)]))
    return lstRet if ngrams[0]!=1 else lst+lstRet

# %%
count_vect = SimpleCountVectorizer(
    doc_cleaner_func=my_doc_cleaner,
    tokenizer_func=my_tokenizer_func
)
count_vect.fit(all_questions)
# Out:
# HBox(children=(IntProgress(value=0, max=646864), HTML(value='')))
# SimpleCountVectorizer(doc_cleaner_func=<function my_doc_cleaner at 0x7fbc240506a8>,
#                       doc_cleaner_pattern='[^a-zA-Z]',
#                       dtype=<class 'numpy.float32'>, min_word_counts=1,
#                       token_pattern='(?u)\\b\\w\\w+\\b',
#                       tokenizer_func=<function my_tokenizer_func at 0x7fbc240509d8>,
#                       word_transformer_func=None)

# %%
def get_features_from_df(df, vectorizer):
    """
    returns a sparse matrix containing the features build by the count vectorizer.
    Each row should contain features from question1 and question2.
    """
    q1_casted =  cast_list_as_strings(list(df["question1"]))
    q2_casted =  cast_list_as_strings(list(df["question2"]))
    
    q1 = vectorizer.transform(q1_casted)
    q2 = vectorizer.transform(q2_casted)
    
    X_q1q2 = scipy.sparse.hstack((q1,q2))
        
    return X_q1q2

# %%
# %time X_tr_q1q2 = get_features_from_df(train_df,count_vect)
# %time X_te_q1q2  = get_features_from_df(test_df, count_vect)

X_tr_q1q2.shape, train_df.shape, test_df.shape, X_te_q1q2.shape
# Out:
# ((323432, 6166022), (323432, 6), (80858, 6), (80858, 6166022))

# %%
y_train = train_df["is_duplicate"].values
y_test = test_df['is_duplicate'].values

# %% [markdown]
# ## Linear Regression

# %%
logistic = sklearn.linear_model.LogisticRegression(solver="liblinear", verbose=1, max_iter=100)
logistic.fit(X_tr_q1q2, y_train)
# Out:
# [LibLinear]
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='liblinear',
#           tol=0.0001, verbose=1, warm_start=False)

# %%
logistic.score(X_tr_q1q2, y_train), logistic.score(X_te_q1q2, y_test)
# Out:
# (0.9963670879813995, 0.8085285314996661)

# %% [markdown]
# ## XGBoost

# %%
# import xgboost as xgb
# from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import accuracy_score

# # PARAM GRID
# param_grid = {}
# param_grid['objective'] = 'binary:logistic'
# param_grid['eval_metric'] = ['auc', 'logloss']   #error: (wrong cases)/#(all cases)
# param_grid['eta'] = 0.02
# param_grid['max_depth'] = 10
# param_grid['n_estimators'] = 300

# d_train = xgb.DMatrix(X_tr_q1q2, label=y_train)  # For sparse matrices
# d_valid = xgb.DMatrix(X_te_q1q2, label=y_test)

# watchlist = [(d_train, 'train'), (d_valid, 'valid')]

# bst = xgb.train(param_grid, d_train, 300, watchlist, early_stopping_rounds=10, verbose_eval=5, )
# #300 # train-auc:0.818362	train-logloss:0.527855	valid-auc:0.801083	valid-logloss:0.53815

# %%
import xgboost as xgb

N = 10000 # With early stopping
xgb_model = xgb.XGBClassifier(n_estimators=N)
xgb_model.fit(X_tr_q1q2, y_train, 
              verbose=10, 
              eval_set=[(X_tr_q1q2, y_train),(X_te_q1q2, y_test)], 
              early_stopping_rounds =10,
              eval_metric=['auc','logloss'],
              )
# Out:
# [0]	validation_0-auc:0.61862	validation_0-logloss:0.66116	validation_1-auc:0.61829	validation_1-logloss:0.66139
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [10]	validation_0-auc:0.74911	validation_0-logloss:0.58040	validation_1-auc:0.74669	validation_1-logloss:0.58202
# [20]	validation_0-auc:0.77399	validation_0-logloss:0.55800	validation_1-auc:0.76904	validation_1-logloss:0.56121
# [30]	validation_0-auc:0.79009	validation_0-logloss:0.54251	validation_1-auc:0.78377	validation_1-logloss:0.54671
# [40]	validation_0-auc:0.80018	validation_0-logloss:0.53168	validation_1-auc:0.79315	validation_1-logloss:0.53663
# [50]	validation_0-auc:0.81140	validation_0-logloss:0.52094	validation_1-auc:0.80380	validation_1-logloss:0.52644
# [60]	validation_0-auc:0.81732	validation_0-logloss:0.51410	validation_1-auc:0.80909	validation_1-logloss:0.52034
# [70]	validation_0-auc:0.82280	validation_0-logloss:0.50830	validation_1-auc:0.81393	validation_1-logloss:0.51526
# [80]	validation_0-auc:0.82669	validation_0-logloss:0.50377	validation_1-auc:0.81666	validation_1-logloss:0.51159
# [90]	validation_0-auc:0.82984	validation_0-logloss:0.49988	validation_1-auc:0.81912	validation_1-logloss:0.50835
# [100]	validation_0-auc:0.83442	validation_0-logloss:0.49388	validation_1-auc:0.82298	validation_1-logloss:0.50324
# [110]	validation_0-auc:0.83706	validation_0-logloss:0.49066	validation_1-auc:0.82496	validation_1-logloss:0.50067
# [120]	validation_0-auc:0.84176	validation_0-logloss:0.48465	validation_1-auc:0.82921	validation_1-logloss:0.49539
# [130]	validation_0-auc:0.84414	validation_0-logloss:0.48172	validation_1-auc:0.83091	validation_1-logloss:0.49307
# [140]	validation_0-auc:0.84682	validation_0-logloss:0.47839	validation_1-auc:0.83301	validation_1-logloss:0.49045
# [150]	validation_0-auc:0.84951	validation_0-logloss:0.47545	validation_1-auc:0.83494	validation_1-logloss:0.48827
# [160]	validation_0-auc:0.85170	validation_0-logloss:0.47285	validation_1-auc:0.83673	validation_1-logloss:0.48618
# [170]	validation_0-auc:0.85356	validation_0-logloss:0.47016	validation_1-auc:0.83836	validation_1-logloss:0.48388
# [180]	validation_0-auc:0.85534	validation_0-logloss:0.46812	validation_1-auc:0.83964	validation_1-logloss:0.48236
# [190]	validation_0-auc:0.85728	validation_0-logloss:0.46577	validation_1-auc:0.84096	validation_1-logloss:0.48066
# [200]	validation_0-auc:0.85908	validation_0-logloss:0.46327	validation_1-auc:0.84242	validation_1-logloss:0.47861
# [210]	validation_0-auc:0.86057	validation_0-logloss:0.46140	validation_1-auc:0.84339	validation_1-logloss:0.47731
# [220]	validation_0-auc:0.86185	validation_0-logloss:0.45968	validation_1-auc:0.84418	validation_1-logloss:0.47609
# [230]	validation_0-auc:0.86348	validation_0-logloss:0.45774	validation_1-auc:0.84527	validation_1-logloss:0.47476
# [240]	validation_0-auc:0.86495	validation_0-logloss:0.45589	validation_1-auc:0.84619	validation_1-logloss:0.47351
# [250]	validation_0-auc:0.86602	validation_0-logloss:0.45450	validation_1-auc:0.84693	validation_1-logloss:0.47251
# [260]	validation_0-auc:0.86760	validation_0-logloss:0.45255	validation_1-auc:0.84803	validation_1-logloss:0.47113
# [270]	validation_0-auc:0.86877	validation_0-logloss:0.45095	validation_1-auc:0.84874	validation_1-logloss:0.47009
# [280]	validation_0-auc:0.86964	validation_0-logloss:0.44969	validation_1-auc:0.84937	validation_1-logloss:0.46916
# [290]	validation_0-auc:0.87136	validation_0-logloss:0.44735	validation_1-auc:0.85059	validation_1-logloss:0.46747
# [300]	validation_0-auc:0.87257	validation_0-logloss:0.44561	validation_1-auc:0.85140	validation_1-logloss:0.46625
# [310]	validation_0-auc:0.87372	validation_0-logloss:0.44400	validation_1-auc:0.85215	validation_1-logloss:0.46516
# [320]	validation_0-auc:0.87460	validation_0-logloss:0.44290	validation_1-auc:0.85279	validation_1-logloss:0.46440
# [330]	validation_0-auc:0.87560	validation_0-logloss:0.44116	validation_1-auc:0.85344	validation_1-logloss:0.46320
# [340]	validation_0-auc:0.87648	validation_0-logloss:0.44009	validation_1-auc:0.85383	validation_1-logloss:0.46262
# [350]	validation_0-auc:0.87720	validation_0-logloss:0.43909	validation_1-auc:0.85428	validation_1-logloss:0.46193
# [360]	validation_0-auc:0.87826	validation_0-logloss:0.43776	validation_1-auc:0.85487	validation_1-logloss:0.46115
# [370]	validation_0-auc:0.87916	validation_0-logloss:0.43665	validation_1-auc:0.85544	validation_1-logloss:0.46043
# [380]	validation_0-auc:0.88023	validation_0-logloss:0.43508	validation_1-auc:0.85617	validation_1-logloss:0.45939
# [390]	validation_0-auc:0.88104	validation_0-logloss:0.43409	validation_1-auc:0.85663	validation_1-logloss:0.45877
# [400]	validation_0-auc:0.88182	validation_0-logloss:0.43313	validation_1-auc:0.85695	validation_1-logloss:0.45829
# [410]	validation_0-auc:0.88266	validation_0-logloss:0.43207	validation_1-auc:0.85755	validation_1-logloss:0.45752
# [420]	validation_0-auc:0.88409	validation_0-logloss:0.42996	validation_1-auc:0.85823	validation_1-logloss:0.45630
# [430]	validation_0-auc:0.88491	validation_0-logloss:0.42894	validation_1-auc:0.85876	validation_1-logloss:0.45564
# [440]	validation_0-auc:0.88592	validation_0-logloss:0.42756	validation_1-auc:0.85941	validation_1-logloss:0.45473
# [450]	validation_0-auc:0.88662	validation_0-logloss:0.42661	validation_1-auc:0.85982	validation_1-logloss:0.45414
# [460]	validation_0-auc:0.88750	validation_0-logloss:0.42543	validation_1-auc:0.86023	validation_1-logloss:0.45348
# [470]	validation_0-auc:0.88815	validation_0-logloss:0.42464	validation_1-auc:0.86069	validation_1-logloss:0.45292
# [480]	validation_0-auc:0.88925	validation_0-logloss:0.42308	validation_1-auc:0.86136	validation_1-logloss:0.45195
# [490]	validation_0-auc:0.88991	validation_0-logloss:0.42212	validation_1-auc:0.86173	validation_1-logloss:0.45138
# [500]	validation_0-auc:0.89055	validation_0-logloss:0.42121	validation_1-auc:0.86206	validation_1-logloss:0.45084
# [510]	validation_0-auc:0.89113	validation_0-logloss:0.42045	validation_1-auc:0.86231	validation_1-logloss:0.45047
# [520]	validation_0-auc:0.89172	validation_0-logloss:0.41951	validation_1-auc:0.86267	validation_1-logloss:0.44984
# [530]	validation_0-auc:0.89279	validation_0-logloss:0.41716	validation_1-auc:0.86340	validation_1-logloss:0.44816
# [540]	validation_0-auc:0.89338	validation_0-logloss:0.41632	validation_1-auc:0.86372	validation_1-logloss:0.44766
# [550]	validation_0-auc:0.89403	validation_0-logloss:0.41545	validation_1-auc:0.86417	validation_1-logloss:0.44707
# [560]	validation_0-auc:0.89451	validation_0-logloss:0.41475	validation_1-auc:0.86443	validation_1-logloss:0.44669
# [570]	validation_0-auc:0.89507	validation_0-logloss:0.41402	validation_1-auc:0.86461	validation_1-logloss:0.44640
# [580]	validation_0-auc:0.89578	validation_0-logloss:0.41307	validation_1-auc:0.86504	validation_1-logloss:0.44583
# [590]	validation_0-auc:0.89639	validation_0-logloss:0.41205	validation_1-auc:0.86538	validation_1-logloss:0.44525
# [600]	validation_0-auc:0.89684	validation_0-logloss:0.41134	validation_1-auc:0.86567	validation_1-logloss:0.44478
# [610]	validation_0-auc:0.89741	validation_0-logloss:0.41055	validation_1-auc:0.86604	validation_1-logloss:0.44433
# [620]	validation_0-auc:0.89786	validation_0-logloss:0.40992	validation_1-auc:0.86629	validation_1-logloss:0.44394
# [630]	validation_0-auc:0.89828	validation_0-logloss:0.40929	validation_1-auc:0.86639	validation_1-logloss:0.44371
# [640]	validation_0-auc:0.89884	validation_0-logloss:0.40856	validation_1-auc:0.86671	validation_1-logloss:0.44327
# [650]	validation_0-auc:0.89935	validation_0-logloss:0.40788	validation_1-auc:0.86696	validation_1-logloss:0.44290
# [660]	validation_0-auc:0.89987	validation_0-logloss:0.40716	validation_1-auc:0.86724	validation_1-logloss:0.44254
# [670]	validation_0-auc:0.90025	validation_0-logloss:0.40655	validation_1-auc:0.86745	validation_1-logloss:0.44218
# [680]	validation_0-auc:0.90070	validation_0-logloss:0.40592	validation_1-auc:0.86772	validation_1-logloss:0.44179
# [690]	validation_0-auc:0.90109	validation_0-logloss:0.40538	validation_1-auc:0.86796	validation_1-logloss:0.44146
# [700]	validation_0-auc:0.90153	validation_0-logloss:0.40475	validation_1-auc:0.86808	validation_1-logloss:0.44122
# [710]	validation_0-auc:0.90225	validation_0-logloss:0.40342	validation_1-auc:0.86857	validation_1-logloss:0.44039
# [720]	validation_0-auc:0.90280	validation_0-logloss:0.40261	validation_1-auc:0.86886	validation_1-logloss:0.43991
# [730]	validation_0-auc:0.90322	validation_0-logloss:0.40199	validation_1-auc:0.86909	validation_1-logloss:0.43960
# [740]	validation_0-auc:0.90356	validation_0-logloss:0.40155	validation_1-auc:0.86919	validation_1-logloss:0.43941
# [750]	validation_0-auc:0.90404	validation_0-logloss:0.40084	validation_1-auc:0.86940	validation_1-logloss:0.43907
# [760]	validation_0-auc:0.90453	validation_0-logloss:0.40010	validation_1-auc:0.86977	validation_1-logloss:0.43859
# [770]	validation_0-auc:0.90497	validation_0-logloss:0.39947	validation_1-auc:0.86992	validation_1-logloss:0.43829
# [780]	validation_0-auc:0.90544	validation_0-logloss:0.39883	validation_1-auc:0.87012	validation_1-logloss:0.43799
# [790]	validation_0-auc:0.90579	validation_0-logloss:0.39831	validation_1-auc:0.87023	validation_1-logloss:0.43778
# [800]	validation_0-auc:0.90619	validation_0-logloss:0.39774	validation_1-auc:0.87035	validation_1-logloss:0.43756
# [810]	validation_0-auc:0.90664	validation_0-logloss:0.39709	validation_1-auc:0.87053	validation_1-logloss:0.43726
# [820]	validation_0-auc:0.90709	validation_0-logloss:0.39642	validation_1-auc:0.87081	validation_1-logloss:0.43685
# [830]	validation_0-auc:0.90753	validation_0-logloss:0.39581	validation_1-auc:0.87096	validation_1-logloss:0.43661
# [840]	validation_0-auc:0.90795	validation_0-logloss:0.39523	validation_1-auc:0.87115	validation_1-logloss:0.43635
# [850]	validation_0-auc:0.90840	validation_0-logloss:0.39452	validation_1-auc:0.87144	validation_1-logloss:0.43590
# [860]	validation_0-auc:0.90870	validation_0-logloss:0.39406	validation_1-auc:0.87162	validation_1-logloss:0.43565
# [870]	validation_0-auc:0.90907	validation_0-logloss:0.39353	validation_1-auc:0.87181	validation_1-logloss:0.43537
# [880]	validation_0-auc:0.90943	validation_0-logloss:0.39299	validation_1-auc:0.87195	validation_1-logloss:0.43515
# [890]	validation_0-auc:0.90995	validation_0-logloss:0.39209	validation_1-auc:0.87232	validation_1-logloss:0.43455
# [900]	validation_0-auc:0.91033	validation_0-logloss:0.39150	validation_1-auc:0.87254	validation_1-logloss:0.43422
# [910]	validation_0-auc:0.91064	validation_0-logloss:0.39103	validation_1-auc:0.87265	validation_1-logloss:0.43406
# [920]	validation_0-auc:0.91098	validation_0-logloss:0.39052	validation_1-auc:0.87282	validation_1-logloss:0.43379
# [930]	validation_0-auc:0.91138	validation_0-logloss:0.38994	validation_1-auc:0.87300	validation_1-logloss:0.43351
# [2220]	validation_0-auc:0.94029	validation_0-logloss:0.34042	validation_1-auc:0.88463	validation_1-logloss:0.41257
# [2230]	validation_0-auc:0.94040	validation_0-logloss:0.34017	validation_1-auc:0.88467	validation_1-logloss:0.41247
# [2240]	validation_0-auc:0.94054	validation_0-logloss:0.33990	validation_1-auc:0.88468	validation_1-logloss:0.41243
# [2250]	validation_0-auc:0.94070	validation_0-logloss:0.33962	validation_1-auc:0.88475	validation_1-logloss:0.41232
# [2260]	validation_0-auc:0.94090	validation_0-logloss:0.33924	validation_1-auc:0.88481	validation_1-logloss:0.41220
# [2270]	validation_0-auc:0.94110	validation_0-logloss:0.33892	validation_1-auc:0.88483	validation_1-logloss:0.41214
# [2280]	validation_0-auc:0.94125	validation_0-logloss:0.33861	validation_1-auc:0.88488	validation_1-logloss:0.41202
# [2290]	validation_0-auc:0.94139	validation_0-logloss:0.33837	validation_1-auc:0.88498	validation_1-logloss:0.41188
# [2300]	validation_0-auc:0.94153	validation_0-logloss:0.33810	validation_1-auc:0.88509	validation_1-logloss:0.41172
# [2310]	validation_0-auc:0.94168	validation_0-logloss:0.33784	validation_1-auc:0.88514	validation_1-logloss:0.41163
# [2320]	validation_0-auc:0.94182	validation_0-logloss:0.33754	validation_1-auc:0.88521	validation_1-logloss:0.41151
# [2330]	validation_0-auc:0.94195	validation_0-logloss:0.33731	validation_1-auc:0.88526	validation_1-logloss:0.41141
# [2340]	validation_0-auc:0.94207	validation_0-logloss:0.33707	validation_1-auc:0.88530	validation_1-logloss:0.41130
# [2350]	validation_0-auc:0.94219	validation_0-logloss:0.33683	validation_1-auc:0.88533	validation_1-logloss:0.41126
# [2360]	validation_0-auc:0.94234	validation_0-logloss:0.33655	validation_1-auc:0.88539	validation_1-logloss:0.41114
# [2370]	validation_0-auc:0.94247	validation_0-logloss:0.33629	validation_1-auc:0.88543	validation_1-logloss:0.41105
# [2380]	validation_0-auc:0.94261	validation_0-logloss:0.33601	validation_1-auc:0.88549	validation_1-logloss:0.41094
# [2390]	validation_0-auc:0.94276	validation_0-logloss:0.33573	validation_1-auc:0.88557	validation_1-logloss:0.41081
# [2400]	validation_0-auc:0.94293	validation_0-logloss:0.33536	validation_1-auc:0.88574	validation_1-logloss:0.41052
# [2410]	validation_0-auc:0.94315	validation_0-logloss:0.33495	validation_1-auc:0.88585	validation_1-logloss:0.41034
# [2420]	validation_0-auc:0.94331	validation_0-logloss:0.33461	validation_1-auc:0.88588	validation_1-logloss:0.41027
# [2430]	validation_0-auc:0.94344	validation_0-logloss:0.33440	validation_1-auc:0.88592	validation_1-logloss:0.41018
# [2440]	validation_0-auc:0.94358	validation_0-logloss:0.33412	validation_1-auc:0.88596	validation_1-logloss:0.41009
# [2450]	validation_0-auc:0.94372	validation_0-logloss:0.33387	validation_1-auc:0.88599	validation_1-logloss:0.41004
# [2460]	validation_0-auc:0.94385	validation_0-logloss:0.33364	validation_1-auc:0.88603	validation_1-logloss:0.40995
# [2470]	validation_0-auc:0.94398	validation_0-logloss:0.33341	validation_1-auc:0.88608	validation_1-logloss:0.40987
# [2480]	validation_0-auc:0.94410	validation_0-logloss:0.33317	validation_1-auc:0.88608	validation_1-logloss:0.40985
# [2490]	validation_0-auc:0.94423	validation_0-logloss:0.33290	validation_1-auc:0.88616	validation_1-logloss:0.40972
# [2500]	validation_0-auc:0.94436	validation_0-logloss:0.33266	validation_1-auc:0.88619	validation_1-logloss:0.40964
# [2510]	validation_0-auc:0.94448	validation_0-logloss:0.33240	validation_1-auc:0.88624	validation_1-logloss:0.40953
# [2520]	validation_0-auc:0.94466	validation_0-logloss:0.33201	validation_1-auc:0.88627	validation_1-logloss:0.40943
# [2530]	validation_0-auc:0.94480	validation_0-logloss:0.33177	validation_1-auc:0.88631	validation_1-logloss:0.40936
# [2540]	validation_0-auc:0.94491	validation_0-logloss:0.33153	validation_1-auc:0.88634	validation_1-logloss:0.40930
# [2550]	validation_0-auc:0.94504	validation_0-logloss:0.33130	validation_1-auc:0.88641	validation_1-logloss:0.40919
# [2560]	validation_0-auc:0.94517	validation_0-logloss:0.33106	validation_1-auc:0.88645	validation_1-logloss:0.40913
# [2570]	validation_0-auc:0.94531	validation_0-logloss:0.33075	validation_1-auc:0.88648	validation_1-logloss:0.40904
# [2580]	validation_0-auc:0.94547	validation_0-logloss:0.33046	validation_1-auc:0.88652	validation_1-logloss:0.40896
# [2590]	validation_0-auc:0.94560	validation_0-logloss:0.33021	validation_1-auc:0.88658	validation_1-logloss:0.40885
# [2600]	validation_0-auc:0.94575	validation_0-logloss:0.32992	validation_1-auc:0.88657	validation_1-logloss:0.40881
# [2610]	validation_0-auc:0.94587	validation_0-logloss:0.32968	validation_1-auc:0.88659	validation_1-logloss:0.40875
# [2620]	validation_0-auc:0.94607	validation_0-logloss:0.32927	validation_1-auc:0.88665	validation_1-logloss:0.40864
# [2630]	validation_0-auc:0.94619	validation_0-logloss:0.32906	validation_1-auc:0.88668	validation_1-logloss:0.40859
# [2640]	validation_0-auc:0.94630	validation_0-logloss:0.32884	validation_1-auc:0.88672	validation_1-logloss:0.40851
# [2650]	validation_0-auc:0.94647	validation_0-logloss:0.32825	validation_1-auc:0.88680	validation_1-logloss:0.40826
# [2660]	validation_0-auc:0.94661	validation_0-logloss:0.32796	validation_1-auc:0.88691	validation_1-logloss:0.40810
# [2670]	validation_0-auc:0.94673	validation_0-logloss:0.32773	validation_1-auc:0.88693	validation_1-logloss:0.40805
# [2680]	validation_0-auc:0.94684	validation_0-logloss:0.32752	validation_1-auc:0.88695	validation_1-logloss:0.40799
# [2690]	validation_0-auc:0.94694	validation_0-logloss:0.32727	validation_1-auc:0.88700	validation_1-logloss:0.40788
# [2700]	validation_0-auc:0.94710	validation_0-logloss:0.32700	validation_1-auc:0.88705	validation_1-logloss:0.40782
# [2710]	validation_0-auc:0.94718	validation_0-logloss:0.32680	validation_1-auc:0.88709	validation_1-logloss:0.40775
# [2720]	validation_0-auc:0.94730	validation_0-logloss:0.32659	validation_1-auc:0.88713	validation_1-logloss:0.40767
# [2730]	validation_0-auc:0.94740	validation_0-logloss:0.32640	validation_1-auc:0.88714	validation_1-logloss:0.40764
# [2740]	validation_0-auc:0.94751	validation_0-logloss:0.32621	validation_1-auc:0.88718	validation_1-logloss:0.40758
# [2750]	validation_0-auc:0.94763	validation_0-logloss:0.32595	validation_1-auc:0.88727	validation_1-logloss:0.40743
# [2760]	validation_0-auc:0.94776	validation_0-logloss:0.32571	validation_1-auc:0.88731	validation_1-logloss:0.40736
# [2770]	validation_0-auc:0.94786	validation_0-logloss:0.32550	validation_1-auc:0.88733	validation_1-logloss:0.40729
# [2780]	validation_0-auc:0.94799	validation_0-logloss:0.32515	validation_1-auc:0.88748	validation_1-logloss:0.40705
# [2790]	validation_0-auc:0.94811	validation_0-logloss:0.32492	validation_1-auc:0.88752	validation_1-logloss:0.40698
# [2800]	validation_0-auc:0.94821	validation_0-logloss:0.32471	validation_1-auc:0.88756	validation_1-logloss:0.40690
# [2810]	validation_0-auc:0.94835	validation_0-logloss:0.32445	validation_1-auc:0.88760	validation_1-logloss:0.40682
# [2820]	validation_0-auc:0.94844	validation_0-logloss:0.32425	validation_1-auc:0.88763	validation_1-logloss:0.40676
# [2830]	validation_0-auc:0.94854	validation_0-logloss:0.32405	validation_1-auc:0.88763	validation_1-logloss:0.40673
# Stopping. Best iteration:
# [2825]	validation_0-auc:0.94849	validation_0-logloss:0.32414	validation_1-auc:0.88763	validation_1-logloss:0.40673
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=10000, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#               validate_parameters=False, verbosity=None)

# %% [markdown]
# ## Plot

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

results = xgb_model.evals_result()
epochs = len(results['validation_0']['logloss'])
x_axis = range(0, epochs)

fig = plt.figure(figsize=(20,6))

# plot log loss
ax = fig.add_subplot(121)
ax.plot(x_axis, results['validation_0']['logloss'], label='Train')
ax.plot(x_axis, results['validation_1']['logloss'], label='Test')
ax.legend()
ax.set_ylabel('Log Loss')
ax.set_title('XGBoost Log Loss')

# plot classification AUC
ax = fig.add_subplot(122)
ax.plot(x_axis, results['validation_0']['auc'], label='Train')
ax.plot(x_axis, results['validation_1']['auc'], label='Test')
ax.legend()
ax.set_ylabel('Classification AUC')
ax.set_title('XGBoost Classification AUC')
plt.show()

# %% [markdown]
# ### GridSearch

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'nthread':[4], 
              'objective':['binary:logistic'],
              'learning_rate': [0.1,0.5,1], 
              'max_depth': [3,5],
              'scale_pos_weight':[1,5,20],
              'min_child_weight': [4,5],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7, 0.9],
              'n_estimators': [50]}

N = 100
xgb_model = xgb.XGBClassifier(n_estimators=N)
grid = GridSearchCV(xgb_model, parameters,
                    n_jobs = 5, scoring='roc_auc',
                    verbose=True)
grid.fit(X_tr_q1q2, y_train)
# Out:
# /opt/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-c42ef8c7cedc> in <module>
#      17                     n_jobs = 5, scoring='roc_auc',
#      18                     verbose=True)
# ---> 19 grid.fit(X_tr_q1q2, y_train)
#
# /opt/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     685                 return results
#     686
# --> 687             self._run_search(evaluate_candidates)
#     688
#     689         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /opt/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1146     def _run_search(self, evaluate_candidates):
#    1147         """Search all candidates in param_grid"""
# -> 1148         evaluate_candidates(ParameterGrid(self.param_grid))
#    1149
#    1150
#
# /opt/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     664                                for parameters, (train, test)
#     665                                in product(candidate_params,
# --> 666                                           cv.split(X, y, groups)))
#     667
#     668                 if len(out) < 1:
#
# /opt/anaconda/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1015
#    1016             with self._backend.retrieval_context():
# -> 1017                 self.retrieve()
#    1018             # Make sure that we get a last message telling us we are done
#    1019             elapsed_time = time.time() - self._start_time
#
# /opt/anaconda/lib/python3.6/site-packages/joblib/parallel.py in retrieve(self)
#     907             try:
#     908                 if getattr(self._backend, 'supports_timeout', False):
# --> 909                     self._output.extend(job.get(timeout=self.timeout))
#     910                 else:
#     911                     self._output.extend(job.get())
#
# /opt/anaconda/lib/python3.6/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     560         AsyncResults.get from multiprocessing."""
#     561         try:
# --> 562             return future.result(timeout=timeout)
#     563         except LokyTimeoutError:
#     564             raise TimeoutError()
#
# /opt/anaconda/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /opt/anaconda/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
def get_mistakes(clf, X_q1q2, y):

    predictions = clf.predict(X_q1q2).astype(int)   
#     print(y[:10])
#     print(predictions[:10])
    incorrect_predictions = predictions!=y
#     print(incorrect_predictions[:10])
#     print(np.where(incorrect_predictions)[:10])
    incorrect_indices = np.where(incorrect_predictions)[0]
    
    if np.sum(incorrect_predictions)==0:
        print("no mistakes in this df")
    else:
        return incorrect_indices, predictions
    
def print_mistake_k(k, mistake_indices, predictions):
    print(train_df.iloc[mistake_indices[k]].question1)
    print(train_df.iloc[mistake_indices[k]].question2)
    print("true class:", train_df.iloc[mistake_indices[k]].is_duplicate)
    print("prediction:", predictions[mistake_indices[k]])
    
def print_mistake_k_and_tokens(k, mistake_indices, predictions,
                               X_q1q2, count_vect, clf):
    q1 = train_df.iloc[mistake_indices[k]].question1
    q2 = train_df.iloc[mistake_indices[k]].question2
    
    print(q1)
    print(count_vect.tokenize(q1))
    print()
    print(q2)
    print(count_vect.tokenize(q2))
    print()
    print("true class:", train_df.iloc[mistake_indices[k]].is_duplicate)
    print("prediction:", predictions[mistake_indices[k]])
    print()
    print("Probability vector: [P(0|x), P(1|x)]:")
    print(clf.predict_proba(X_q1q2)[mistake_indices[k],:])
    
    
def hist_errors(mistake_indices, predictions,
                               X_q1q2, count_vect, clf):
    qs = train_df.iloc[mistake_indices][['question1', 'question2']]
    qs['true_class']=train_df.iloc[mistake_indices].is_duplicate
    qs['prediction']=predictions[mistake_indices]
    qs['P(1|x)']=clf.predict_proba(X_q1q2)[mistake_indices,:][:,1]
    qs = qs.reset_index(drop=True)
    return qs

# %%
mistake_indices, predictions = get_mistakes(xgb_model, X_te_q1q2, y_test)

# %%
xgb_model.save_model('models/xgb_2825its_0.88763auc_0.40673logloss.dat')

# %%
xgb_loaded_model = xgb.XGBClassifier()
xgb_loaded_model._Booster.load_model('models/xgb_2825its_0.88763auc_0.40673logloss.dat')

# %%
len(mistake_indices)
# Out:
# 15343

# %%
print_mistake_k(0, mistake_indices, predictions)
# Out:
# How do I see who is viewing my Instagram videos?
# Can one tell who viewed my Instagram videos?
# true class: 1
# prediction: 1

# %%
print_mistake_k_and_tokens(0, mistake_indices, predictions,
                           X_te_q1q2, count_vect, xgb_model)
# Out:
# How do I see who is viewing my Instagram videos?
# ['how', 'do', 'i', 'see', 'who', 'is', 'view', 'my', 'instagram', 'video', ('how', 'do'), ('do', 'i'), ('i', 'see'), ('see', 'who'), ('who', 'is'), ('is', 'view'), ('view', 'my'), ('my', 'instagram'), ('instagram', 'video'), ('how', 'do', 'i'), ('do', 'i', 'see'), ('i', 'see', 'who'), ('see', 'who', 'is'), ('who', 'is', 'view'), ('is', 'view', 'my'), ('view', 'my', 'instagram'), ('my', 'instagram', 'video')]
#
# Can one tell who viewed my Instagram videos?
# ['can', 'one', 'tell', 'who', 'view', 'my', 'instagram', 'video', ('can', 'one'), ('one', 'tell'), ('tell', 'who'), ('who', 'view'), ('view', 'my'), ('my', 'instagram'), ('instagram', 'video'), ('can', 'one', 'tell'), ('one', 'tell', 'who'), ('tell', 'who', 'view'), ('who', 'view', 'my'), ('view', 'my', 'instagram'), ('my', 'instagram', 'video')]
#
# true class: 1
# prediction: 1
#
# Probability vector: [P(0|x), P(1|x)]:
# [0.31839687 0.68160313]

# %% [markdown]
# # TFIDF

# %%
tfidf_vectorizer = TFIDFVectorizer(count_vect.vocabulary, count_vect.word_to_ind, count_vect.tokenize)
tfidf_vectorizer.fit(all_questions)
# Out:
# TFIDF fit finished in 181.48 seconds

# %%
X_tfidf_tr_q1q2 = get_features_from_df(train_df, tfidf_vectorizer)
X_tfidf_te_q1q2  = get_features_from_df(test_df, tfidf_vectorizer)

X_tfidf_tr_q1q2.shape, train_df.shape, test_df.shape, X_tfidf_te_q1q2.shape
# Out:
# TFIDF transform finished in 91.75 seconds
# TFIDF transform finished in 93.02 seconds
# TFIDF transform finished in 22.81 seconds
# TFIDF transform finished in 23.93 seconds
# ((323432, 6166022), (323432, 6), (80858, 6), (80858, 6166022))

# %%
logistic = sklearn.linear_model.LogisticRegression(solver="liblinear", verbose=1, max_iter=100)
logistic.fit(X_tfidf_tr_q1q2, y_train)
# Out:
# [LibLinear]
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=1,
#                    warm_start=False)

# %%
logistic.score(X_tfidf_tr_q1q2, y_train), logistic.score(X_tfidf_te_q1q2, y_test)
# Out:
# (0.9006499047713276, 0.7898167157238616)

# %%
mistake_indices, predictions = get_mistakes(logistic, X_tfidf_te_q1q2, y_test)

# %%
print_mistake_k(0, mistake_indices, predictions)
# Out:
# How do I study for Honeywell company recruitment?
# How do I study for Honeywell company recruitments?
# true class: 1
# prediction: 0

# %%
print_mistake_k_and_tokens(0, mistake_indices, predictions,
                           X_tfidf_te_q1q2, tfidf_vectorizer, logistic)
# Out:
# How do I study for Honeywell company recruitment?
# ['how', 'do', 'i', 'studi', 'for', 'honeywel', 'compani', 'recruit', ('how', 'do'), ('do', 'i'), ('i', 'studi'), ('studi', 'for'), ('for', 'honeywel'), ('honeywel', 'compani'), ('compani', 'recruit'), ('how', 'do', 'i'), ('do', 'i', 'studi'), ('i', 'studi', 'for'), ('studi', 'for', 'honeywel'), ('for', 'honeywel', 'compani'), ('honeywel', 'compani', 'recruit')]
#
# How do I study for Honeywell company recruitments?
# ['how', 'do', 'i', 'studi', 'for', 'honeywel', 'compani', 'recruit', ('how', 'do'), ('do', 'i'), ('i', 'studi'), ('studi', 'for'), ('for', 'honeywel'), ('honeywel', 'compani'), ('compani', 'recruit'), ('how', 'do', 'i'), ('do', 'i', 'studi'), ('i', 'studi', 'for'), ('studi', 'for', 'honeywel'), ('for', 'honeywel', 'compani'), ('honeywel', 'compani', 'recruit')]
#
# true class: 1
# prediction: 0
#
# Probability vector: [P(0|x), P(1|x)]:
# [0.73466044 0.26533956]

# %%
######### SEARCH QUESTIONS WITH SAME TOKENS ###########

q1_casted =  cast_list_as_strings(list(train_df["question1"]))
q2_casted =  cast_list_as_strings(list(train_df["question2"]))

q1 = count_vect.transform(q1_casted)
q2 = count_vect.transform(q2_casted)

same_tokens_idxs = []
for i in range(len(q1_casted)):
    same_features = ( q1[i] != q2[i] ).nnz == 0
    if same_features:
        same_tokens_idxs.append(i)
    if i % 500 == 0: print(i)

same_tokens_idxs = np.array(same_tokens_idxs)


same_tokens = train_df.iloc[same_tokens_idxs]
duplicates = same_tokens['is_duplicate'] == 1
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000
# 11500
# 12000
# 12500
# 13000
# 13500
# 14000
# 14500
# 15000
# 15500
# 16000
# 16500
# 17000
# 17500
# 18000
# 18500
# 19000
# 19500
# 20000
# 20500
# 21000
# 21500
# 22000
# 22500
# 23000
# 23500
# 24000
# 24500
# 25000
# 25500
# 26000
# 26500
# 27000
# 27500
# 28000
# 28500
# 29000
# 29500
# 30000
# 30500
# 31000
# 31500
# 32000
# 32500
# 33000
# 33500
# 34000
# 34500
# 35000
# 35500
# 36000
# 36500
# 37000
# 37500
# 38000
# 38500
# 39000
# 39500
# 40000
# 40500
# 41000
# 41500
# 42000
# 42500
# 43000
# 43500
# 44000
# 44500
# 45000
# 45500
# 46000
# 46500
# 47000
# 47500
# 48000
# 48500
# 49000
# 49500
# 50000
# 50500
# 51000
# 51500
# 52000
# 52500
# 53000
# 53500
# 54000
# 54500
# 55000
# 55500
# 56000
# 56500
# 154             How do I overcome my inferiority complex?             0
# 170          How can I make money as a thirteen year old?             0
# 246             What are the most haunted place in delhi?             0
# 1723    What language is used in Visual Basic? How doe...             0
# 2145               What are the best things about models?             0
# ...                                                   ...           ...
# 316104                What is the definition of blogging?             0
# 316373    What is the difference between ":=" and "::=" ?             0
# 317754                    What does this '≜' symbol mean?             0
# 318279                             What is refrigeration?             0
# 319355                                     What is timee?             0
#
# [230 rows x 6 columns]

# %%
same_tokens[duplicates]
# Out:
#             id    qid1    qid2  \
# 1       327668  454117  345117
# 163     251786  317853   86925
# 873     351007  479805  479806
# 1644    383603  474670   70140
# 1857    346791  421809  140365
# ...        ...     ...     ...
# 322629  302747  425769  425770
# 322814  272376  390622  390623
# 322882  115624  188516  188517
# 323043  256986  372216  372217
# 323320   76582  130894  130895
#
#                                                 question1  \
# 1       How do I study for Honeywell company recruitment?
# 163      How do I get permanent residence in New Zealand?
# 873                       What is Open source technology?
# 1644               Who will be the next president of US ?
# 1857       What are some examples of vertebrated animals?
# ...                                                   ...
# 322629      How is the word 'servile' used in a sentence?
# 322814  Is there any good reading room available near ...
# 322882  Two hot copper and steel balls long sitting in...
# 323043                  Do virus and Bacteria have souls?
# 323320  What's the best website in which I can take up...
#
#                                                 question2  is_duplicate
# 1       How do I study for Honeywell company recruitme...             1
# 163      How do I get permanent residency in New Zealand?             1
# 873                     What is open source technologies?             1
# 1644                Who will be the next president of US?             1
# 1857        What are some examples of vertebrate animals?             1
# ...                                                   ...           ...
# 322629      How is the word "servile" used in a sentence?             1
# 322814  Is there any good reading room available near ...             1
# 322882  Two hot copper and steel balls long sitting in...             1
# 323043                Do viruses and bacteria have souls?             1
# 323320  Whats the best website in which I can take up ...             1
#
# [1342 rows x 6 columns]

# %%
same_tokens[~duplicates]
# Out:
#             id    qid1    qid2  \
# 154       3148    6241    6242
# 170      15678   29935   29936
# 246     403514  253677  537096
# 1723    290549   26661   70364
# 2145    184520  281899  281900
# ...        ...     ...     ...
# 316104   45535   81584   81585
# 316373  288872  294219  122887
# 317754  248848  285169  362342
# 318279  102122  169021  169022
# 319355  273876  392410  392411
#
#                                                 question1  \
# 154            How do I overcome my inferiority complex ?
# 170                How can I make money as a 13 year old?
# 246            What are the most haunted places in delhi?
# 1723    What language is used in Visual Basic? How doe...
# 2145             What are the best things about modeling?
# ...                                                   ...
# 316104                    What is the definition of blog?
# 316373           What is the difference between : and ; ?
# 317754                        What does this symbol mean?
# 318279                               What is refrigerant?
# 319355                                    What is Timing?
#
#                                                 question2  is_duplicate
# 154             How do I overcome my inferiority complex?             0
# 170          How can I make money as a thirteen year old?             0
# 246             What are the most haunted place in delhi?             0
# 1723    What language is used in Visual Basic? How doe...             0
# 2145               What are the best things about models?             0
# ...                                                   ...           ...
# 316104                What is the definition of blogging?             0
# 316373    What is the difference between ":=" and "::=" ?             0
# 317754                    What does this '≜' symbol mean?             0
# 318279                             What is refrigeration?             0
# 319355                                     What is timee?             0
#
# [230 rows x 6 columns]
